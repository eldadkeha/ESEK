# %% [markdown]
# <a href="https://colab.research.google.com/github/eldadkeha/ESEK/blob/master/Effectsizes8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##to do
#check out lakens excel
#ADD OPTIONAL FOR POPULATION
#Deal with special chrecters
#consider adding the population difference to the formula
## 1.cohens U3 4.Q = Wilcox & Muska’s Q  5.The Kolmogorov-Smirnov test statistic. 6.Dunlap 7.Agina 8.Cochran Q ((Mulrow and Oxman, 1996))
##Non parametric effect sizes - cliffs delta (Macbath et al)
##How to deal with outliers? use grissom and kim options (see page 75)
#glass d unbiased
#Type 1 errors unequal groups in ANOVA
#Check MOTE for r
#Zfactor from biology
# Consider using the Standart errors 
#Check Out all the buttons...
#Noncentrality


import ipywidgets as widgets
from ipywidgets import Image, interactive, interact_manual, Layout, HBox, VBox, Button, ButtonStyle, Accordion, Text, Dropdown
from scipy import stats 
from scipy.stats import norm
import numpy as np
import math
import colorama
from colorama import Fore, Back
from IPython.display import HTML
from datetime import datetime
start_time = datetime.now()

#Loading pictures
file = open("Cohensd.png", "rb"); image = file.read();
file = open("hedges.png", "rb");  image1 = file.read();
file = open("Cohensz.png", "rb"); image2 = file.read();
file = open("Cohenst.png", "rb"); image3 = file.read();
file = open("cohensp.png", "rb"); image4 = file.read();
file = open("indsamp1.png", "rb"); image7 = file.read();
file = open("bessels.png", "rb");  image8 = file.read();

###########################################################################################################################
##############################################   One Sample Z Test   ######################################################
########                                                                                                            #######
###########################################################################################################################                                                                                                            
###########################################################################################################################

#headers
hbox1_1 = widgets.HTML(value= '<p style = "word-wrap: break-word; color: black; font-size: 140%; text-align: center;" > <b><u> Calculate Effect Size From Z-Score </u></b> </p>')
hbox1_2 = widgets.HTML(value= '<p style = "word-wrap: break-word; color: black; font-size: 140%; text-align: center;" > <b><u> Calculate Effect Size From Parameters </u></b> </p>')
hbox1_3 = widgets.HTML(value= '<style>p{word-wrap: break-word; color: indianred; font-size: 180%; text-align: center}</style> <p> <b><u> Cohen`s d Interpretation <u></b> </p>')
###########################################################################################################################

############################# Box 1_1 - One Sample Z test ###################################################################
def Z_test1(Z_score, SampleN):
    if (any(i.isalpha() for i in Z_score)) !=True and SampleN.isdigit() == True and (",") not in Z_score:
       Z_score = float(Z_score); SampleN = float(SampleN)
       pval = min((stats.t.sf((abs(Z_score)), 100000)*2), 0.99999)
       d = (Z_score/np.sqrt(SampleN))
       print(f"p-value(2-tailed) = {round(pval,7)}\nCohen's d = {round(d,7)}")
    elif Z_score == "":
        print(Fore.RED + "Missing: Please define Z-score")
    elif SampleN == "":
        print(Fore.RED + "Missing: Please define Sample size")
    else:
        print(Fore.YELLOW + Back.RED + "Warnning!!! You have just entered an illegal character")
           
#Text and explanations
accordionz = widgets.Accordion(children=[
    widgets.Image(value=image2,format='png',width=300,height=400,), 
    widgets.HTML(value= '<p style = "word-wrap: break-word; color: black; font-size: 140%; text-align: left;"> Cohens` d for one sample z test (Cohen, 1988), is the most basic effect size. Since the variance is known, it makes it simple to use the standart deviation of the population. The whole difference from the Z-statistic is that we don`t devide the standart deviation by square root of n and this is why we can devide our Z-score in the square root of n to get the effect size</p>', width = "400px", height = "auto" ),],)
accordionz.set_title(0, 'Click Here to see the formulae');
accordionz.set_title(1, 'Click Here for more information');
accordionz.selected_index = None

#Styling
style = {'description_width': 'initial'}    
Z1 = interactive(Z_test1, {'manual': True}, Z_score="", SampleN = "")
Z1.children[0].layout = Layout(width='200px')
Z1.children[1].layout = Layout(width='200px')
Z1.children[2].layout = Layout(width='250px')
Z1.children[0].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;"> Z-Score </span> <span style="color: white;">____</span> </p>'
Z1.children[1].description = "<b>Sample Size </b>"
Z1.children[2].description="Calculate Cohen's d"
Z1.children[0].style = style
Z1.children[1].style = style
Z1.children[2].style.button_color="lightblue"
Z1.children[2].style.font_weight = "bold"

#Box 1_1 final objects
box1_1 = VBox([Z1,accordionz])
box1_1.layout = Layout(border="solid 5px lightblue", margin="10px 10px 10px 10px", padding="10px 10px 10px 10px", width = "350px", height = "435px")
box1_1.children[1].layout = Layout(padding="5px 0px 0px 0px", width = "auto", height = "auto")


############################# Box 1_2 - One sample Z test ###################################################################
def Z_test2(MeanP, MeanS, Sig, sampsize):
    if any(i.isalpha() for i in MeanP) != True and any(i.isalpha() for i in MeanS) !=True and any(i.isalpha() for i in Sig) !=True and Sig>"0" and sampsize.isdigit()==True and "," not in Sig and "," not in MeanP and "," not in MeanS and (MeanP and Sig and MeanS and sampsize) !="":
        MeanP = float(MeanP); sampsize = float(sampsize); MeanS = float(MeanS); Sig = float(Sig); 
        SE = Sig/np.sqrt(sampsize)
        Z = abs((MeanP - MeanS)/SE)
        d = abs((MeanP - MeanS)/Sig)
        pval = min((stats.t.sf((abs(Z)), 100000)*2), 0.99999)
        print(f"p-value(2-tailed) = {round(pval,7)}\nCohen's d = {round(d,7)},  Z = {round(Z,7)}\nStandart Error = {round(SE,7)}")
    elif MeanP == "":
        print(Fore.RED + "Missing: Please define Population's mean")
    elif Sig == "":
        print(Fore.RED + "Missing: Please define Population's SD")
    elif MeanS == "":
        print(Fore.RED + "Missing: Please define Sample's mean")
    elif sampsize == "":
        print(Fore.RED + "Missing: Please define Sample size")
    else:
        print(Fore.YELLOW + Back.RED + "Warnning!!! You have just entered an illegal character")
        
#Styling
style = {'description_width': 'initial'}    
Z2 = interactive(Z_test2, {'manual': True}, MeanP="", MeanS = "", Sig = "", sampsize = "", style = style)
Z2.children[0].layout = Layout(width='200px', padding= "0px 10px 0px 0px")
Z2.children[1].layout = Layout(width='182px')
Z2.children[2].layout = Layout(width='200px', padding= "0px 10px 0px 0px")
Z2.children[3].layout = Layout(width='182px')
Z2.children[0].style = style
Z2.children[1].style = style
Z2.children[2].style = style
Z2.children[3].style = style
Z2.children[0].description = " <b> Population's Mean </b>"
Z2.children[1].description = "<b> Sample's Mean </b>"
Z2.children[2].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;"> Population`s SD </span> <span style="color: white;">__</span> </p>'
Z2.children[3].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;"> Sample Size </span> <span style="color: white;">.__</span> </p>'

Z2.children[4].style.button_color="lightblue"
Z2.children[4].description="Calculate Cohen's d"
Z2.children[4].style.font_weight = "bold"
Z2.children[4].layout = Layout(width='250px', padding= "0px 10px 0px 0px")

controls1 = VBox([
          HBox([Z2.children[0],Z2.children[1]]),
          HBox([Z2.children[2],Z2.children[3]]),
          HBox([Z2.children[4]])])
output1 = Z2.children[-1]


Z3 = widgets.Image(value=image,format='png',width=410,height=150, )

box1_2 = VBox([controls1,output1,hbox1_3, Z3])
box1_2.layout = Layout(border="solid 5px lightblue", margin="10px 10px 10px 10px", padding="10px 10px 10px 10px", width = "455PX", height = "435px")
box1_2.children[2].layout = Layout(padding="0px 0px 0px 0px", width = "400PX")
box1_2.children[3].layout = Layout(padding="0px 5px 0px 5px", margin = "0px")


############################  Z-BOX fINAL #############################################################
box1 = HBox([
            VBox([hbox1_1,box1_1]),
            VBox([hbox1_2,box1_2])])
box1.layout = Layout(border="solid 2px indianred", margin="10px 10px 10px 10px", padding="10px 10px 10px 10px", width = "850px", height = "auto")
############################# Z BOX final #############################################################


###########################################################################################################################
##############################################   One Sample t Test   ######################################################
########                                                                                                            #######
###########################################################################################################################                                                                                                            
###########################################################################################################################

#headers
hbox2_1 = widgets.HTML(value= '<p style = "word-wrap: break-word; color: black; font-size: 140%; text-align: center;" > <b><u> Calculate Effect Size From t-Score </u></b> </p>')
hbox2_2 = widgets.HTML(value= '<p style = "word-wrap: break-word; color: black; font-size: 140%; text-align: center;" > <b><u> Calculate Effect Size From Parameters </u></b> </p>')
hbox2_3 = widgets.HTML(value= '<p style = "word-wrap: break-word; color: black; font-size: 140%; text-align: left;" > <b><u> Calculate Unbaised Effect Size </u></b> </p>')
###########################################################################################################################


######################################## Box2_1 - One Sample t-test ######################################
def t_test1(t_score, sampsize):
    if (any(i.isalpha() for i in t_score)) !=True and sampsize.isdigit() == True and (",") not in t_score:
      t_score = float(t_score); sampsize = float(sampsize) 
      pval = min(((stats.t.sf((abs(t_score)), (sampsize-1)))*2), 0.99999)
      d = abs((t_score)/(np.sqrt(sampsize)))
      print(f"p-value(2-tailed) = {round(pval,7)}\nCohen's d= {round(d,7)}")
    elif t_score == "":
       print(Fore.RED + "Missing: Please define t_value")
    elif sampsize == "":
       print(Fore.RED + "Missing: Please define Sample size") 
    else:
        print(Fore.YELLOW + Back.RED + "Warnning!!! You have just entered an illegal character")

    
#Styling
t1 = interactive(t_test1, {'manual': True}, t_score ="", sampsize = "")
t1.children[0].layout = Layout(width='200px') 
t1.children[1].layout = Layout(width='200px') 
t1.children[1].description = "<b>Sample Size </b>"
t1.children[0].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;"> t score </span> <span style="color: white;">_____</span> </p>'
t1.children[2].style.button_color="lightblue"
t1.children[2].description="Calculate Cohen's d";
t1.children[2].style.font_weight = "bold"
t1.children[2].layout = Layout(width='250px')
t1.children[1].style = style
t1.children[0].style = style
t1.children[1].style = style

accordiont = widgets.Accordion(children=[
    widgets.HTML(value= '<p style = "word-wrap: break-word; color: black; font-size: 140%; text-align: left;"> Cohens` d for one sample t test (Cohen, 1988) is using the standart deviation of the sample instead of the unknown standart deviation of the population. Note that the formula uses tha standart deviation of the sample instead of the standart deviation of the popoulation and therfore it is also called the estimated effect size. It is possible to directly get the estimated effect size by multiplying the t-score in the square root of n. </p>', width = "400px", height = "auto" ),
    widgets.HTML(value= '<p style = "word-wrap: break-word; color: black; font-size: 140%; text-align: left;"> Hedges in 1981 argued that the original effect size that was suggested by Cohen`s d is a biased estimator, especially in small samples, and proposed a correction factor to correct for Cohen`s d`s bias (see the formula section). therfore it is recommended to use this version of effect size in small samples. In large samples cohens d and hedges g would be almost equivalent. Finally note that the original correction that was suggested by hedges and uses the Gamma distribution can get a very good approximation with a simple calculation (see the formulae section). Note that both Cohens d and Hedge`s g has the same interpretation (0.8,0.5,0.2 for large, medium and small effect respectively) </p>', width = "400px", height = "auto" ),
    widgets.Image(value=image3,format='png',width=300,height=400,), 
    widgets.Image(value=image1,format='png',width=300,height=400,),],)
accordiont.set_title(0, 'More info on Cohens d');
accordiont.set_title(1, 'More info on the unbaised hedges` g');
accordiont.set_title(2, 'Click Here for Cohens d formulae');
accordiont.set_title(3, 'Click Here for Hedges`g formulae');

accordiont.selected_index = None


box2_1 = VBox([t1, accordiont]); 
box2_1.layout = Layout(border="solid 5px lightblue", margin="10px", padding="10px", width = "400px", height = "440px")


######################################## Box2_2 - One Sample t-test ######################################
def t_test2(MeanP, MeanS, Sig, sampsize):
    if any(i.isalpha() for i in MeanP) != True and any(i.isalpha() for i in MeanS) !=True and any(i.isalpha() for i in Sig) !=True and Sig>"0" and sampsize.isdigit()==True and "," not in Sig and "," not in MeanP and "," not in MeanS and (MeanP and Sig and MeanS and sampsize) !="":
        MeanP = float(MeanP); sampsize = float(sampsize); MeanS = float(MeanS); Sig = float(Sig);
        df = int(sampsize)-1
        SE1 = float(Sig)/np.sqrt(df)
        difference = abs(MeanP - MeanS)
        cohensd = abs((difference/Sig))
        t_1 = difference/SE1
        pval = min(((stats.t.sf((abs(t_1)), (sampsize-1)))*2), 0.99999)
        print(f"p-value(2-tailed)= {round(pval,7)}\nCohen's d = {round(cohensd,7)}, t = {round(t_1,7)} \nStandart Error= {round(SE1,7)}")
    elif MeanP == "":
        print(Fore.RED + "Missing: Please define Population's mean")
    elif Sig == "":
        print(Fore.RED + "Missing: Please define Sample's SD")
    elif MeanS == "":
        print(Fore.RED + "Missing: Please define Sample's mean")
    elif sampsize == "":
        print(Fore.RED + "Missing: Please define Sample size") 
    else:
        print(Fore.YELLOW + Back.RED + "Warnning!!! You have just entered an illegal character")

#Styling
style = {'description_width': 'initial'}    
t2 = interactive(t_test2, {'manual': True}, MeanP="", MeanS = "", Sig = "", sampsize = "", style = style)
t2.children[0].layout = Layout(width='200px', padding = "0px 10px 0px 0px")
t2.children[1].layout = Layout(width='200px')
t2.children[2].layout = Layout(width='200px', padding = "0px 10px 0px 0px") 
t2.children[3].layout = Layout(width='200px')
t2.children[0].style = style
t2.children[1].style = style
t2.children[2].style = style
t2.children[3].style = style
t2.children[0].description = " <b> Population's Mean </b>"
t2.children[1].description = "<b> Sample's Mean </b>" 
t2.children[2].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;"> Sample`s SD </span> <span style="color: white;">______</span> </p>'
t2.children[3].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;"> Sample Size </span> <span style="color: white;">___</span> </p>' 
t2.children[4].style.button_color="lightblue"
t2.children[4].description="Calculate Cohen's d";
t2.children[4].style.font_weight = "bold" 
t2.children[4].layout = Layout(width='275px')
t2.layout = Layout(border="solid 5px lightblue", margin="0px", padding="10px", width = "auto", height = "auto")

controls2_2 = VBox([
          HBox([t2.children[0],t2.children[1]]),
          HBox([t2.children[2],t2.children[3]]),
          HBox([t2.children[4]])])

output2_2 = t2.children[-1]


################################################### box2_3 - One sample t-test############################################################
def t_test3(cohensd, sampsize):
    if (any(i.isalpha() for i in cohensd)) !=True and sampsize.isdigit() == True and (",") not in cohensd:
        cohensd = float(cohensd); sampsize = float(sampsize)
        df = sampsize - 1; 
        correction = 1-(3/(4*df-1))
        hedg = abs(cohensd*correction); 
        print(f"Hedges` g= {round(hedg,7)}")
    elif cohensd == "":
        print(Fore.RED + "Missing: Please define Cohen`s d")
    elif sampsize == "":
        print(Fore.RED + "Missing: Please define Sample size") 
    else:
        print(Fore.YELLOW + Back.RED + "Warnning!!! You have just entered an illegal character")

#Styling
style = {'description_width': 'initial'}    
t3 = interactive(t_test3, {'manual': True}, cohensd="", sampsize = "")
t3.children[0].layout = Layout(width='170px',padding = "0px 20px 0px 0px")
t3.children[1].layout = Layout(width='170px') 
t3.children[1].description = "<b>Sample Size </b>"
t3.children[0].description = "<b> Cohen's d </b>"
t3.children[2].style.button_color="lightblue"
t3.children[2].description="Calculate the unbaised Hedges` g for small samples"
t3.children[2].style.font_weight = "bold" 
t3.children[2].layout = Layout(width='350px')
t3.children[1].style = style
t3.children[0].style = style

controls2_3 = VBox([
          HBox([t3.children[0],t3.children[1]]),
          HBox([t3.children[2]])])

output2_3 = t3.children[-1]

box2_2 = VBox([controls2_2, output2_2, hbox2_3, controls2_3, output2_3]); 
box2_2.layout = Layout(border="solid 5px lightblue", margin="10px", padding="10px", width = "440px", height = "440px")
box2_2.children[2].layout = Layout(padding="30px 10px 10px 10px", width = "auto", height = "auto")

################################################ box2 Final ####################################################################
box2 = HBox([
            VBox([hbox2_1,box2_1]),
            VBox([hbox2_2,box2_2]),])
box2.layout = Layout(border="solid 1.5px indianred", margin="10px", padding="10px", width = "915px", height = "460px")
        
#################################################################################################################################

###########################################################################################################################
##############################################   One Sample Proportion test   #############################################
########                                                                                                            #######
###########################################################################################################################                                                                                                            
###########################################################################################################################

#headers
pbox1 = widgets.HTML(value= '<p style = "word-wrap: break-word; color: black; font-size: 120%; text-align: center;" > <b><u> Calculate Effect Size from Z </u></b> </p>')
pbox2 = widgets.HTML(value= '<p style = "word-wrap: break-word; color: black; font-size: 120%; text-align: center;" > <b><u> Calculate Effect Size from Parameters </u></b> </p>')
pbox3 = widgets.HTML(value= '<p style = "word-wrap: break-word; color: black; font-size: 120%; text-align: left;" > <b><u> Other Effect Sizes (Cohens` g, Π, and odds/risk ratio) </u></b> </p>')

############################# Box 3_1 = One sample Proportion ###################################################################
def binom_test11(Z_score, SampleN):
    if (any(i.isalpha() for i in Z_score)) !=True and SampleN.isdigit() == True and (",") not in Z_score:
        Z_score = float(Z_score); SampleN=float(SampleN)
        h = (abs(Z_score)*np.sqrt(1/SampleN))*np.sqrt(2)
        pval = min((stats.t.sf((abs(Z_score)), 100000)*2), 0.99999)
        print(f"p-val(2-tailed)={round(pval,7)}\nCohen's h = {round(h,7)}")
    if Z_score == "":
        print(Fore.RED + "Missing: Please define Z_score")
    if SampleN == "":
        print(Fore.RED + "Missing: Please define Sample Size")
    else:
        print(Fore.YELLOW + Back.RED + "Warnning!!! You have just entered an illegal character")

accordionp = widgets.Accordion(children=[
    widgets.HTML(value= '<style>p{word-wrap: break-word}</style> <p>' "now i can write here whatever i want on hedges` and check if there is a text wrapping or not" +' </p>'),
    widgets.HTML(value= '<style>p{word-wrap: break-word}</style> <p>' "Cohen’s g (Cohen, 1988) is specifically for the case where the expected proportion in the population is 0.5 (50%). It is then simply the difference of the sample proportion with this 0.5." +' </p>'),
    widgets.HTML(value= '<style>p{word-wrap: break-word}</style> <p>' "Cohen’s g (Cohen, 1988) is specifically for the case where the expected proportion in the population is 0.5 (50%). It is then simply the difference of the sample proportion with this 0.5." +' </p>'),
    widgets.HTML(value= '<style>p{word-wrap: break-word}</style> <p>' "This effect size is suitable for estimating the accuracy of a single sample when there are two alternatives (forced choice) or more. The one-sample effect size index Π is expressed as the proportion of correct guesses if there had been only two choices from which to select. When there are more than two choices, the Π index converts the proportion of hits to the proportion of hits made if therehad been only two equally likely choices.\n for more information see Rosenthal & Robin, 1989" + '</p>'),
    widgets.Image(value=image4,format='png',width=300,height=400,),
    widgets.Image(value=image4,format='png',width=300,height=400,),]) 
accordionp.set_title(0, 'Effect sizes interpretation'); 
accordionp.set_title(1, 'More info on Cohens h & Cohens g');
accordionp.set_title(2, 'More info on odds ratio and risk ratio');
accordionp.set_title(3, 'More info on Π for proportion of hits');
accordionp.set_title(4, 'More info on Cohens formulae');
accordionp.set_title(5, 'More info on other effect sizes formulae');
accordionp.selected_index = None

#Styling
style = {'description_width': 'initial'}    
p1 = interactive(binom_test11, {'manual': True}, Z_score="", SampleN = "")
p1.children[0].layout = Layout(width='150px');
p1.children[1].layout = Layout(width='150px');
p1.children[1].description = "<b>Sample Size </b>";
p1.children[0].description = "<b>Z Score </b>";
p1.children[2].style.button_color="lightblue";
p1.children[2].description="Calculate Cohen's h";
p1.children[2].style.font_weight = "bold";
p1.children[2].layout = Layout(width='200px')

p1box = VBox([pbox1,p1])

############################# Box 3_2 = One sample Proportion ###################################################################
def binom_test2(p, P, sampsize):
  pdifference = abs((float(p))-(float(P)));
  numerator = float(P) * (1 - float(P));
  SE = np.sqrt(numerator/int(sampsize))
  Z_score = pdifference/SE
  h = abs(1.414213562373*((2*math.asin(np.sqrt(float(p)))) - (2*math.asin(np.sqrt(float(P))))))
  pval = min((stats.t.sf((abs(Z_score)), 100000)*2), 0.99999)
  print(f"p-val(2-tailed) = {round(pval,7)}\nCohen's h = {round(h,7)}")
 
#Styling
p2 = interactive(binom_test2, {'manual': True}, p="", P = "", sampsize = "")
p2.children[0].layout = Layout(width='130px', margin = "1px 10.5px 1px 5px")
p2.children[1].layout = Layout(width='130px', margin = "1px 10px 1px 5px")
p2.children[2].layout = Layout(width='130px') 
p2.children[0].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;"> p Sample </span> <span style="color: white;">__</span> </p>'
p2.children[1].description = "<b> P Population</b>";
p2.children[2].description = "<b>Sample Size </b>"
p2.children[0].style = style;
p2.children[1].style = style;
p2.children[2].style = style;
p2.children[3].style.button_color="lightblue";
p2.children[3].description="Calculate Cohen's h";
p2.children[3].style.font_weight = "bold";
p2.children[3].layout = Layout(width='200px')

controls30 = VBox([
          HBox([p2.children[0],p2.children[1]]),
          HBox([p2.children[2]]),
          HBox([p2.children[3]]),])

output30 = p2.children[-1]

p2_1 = VBox([pbox2, controls30,output30])
p2_1.children[0].layout = Layout(align = "left")

box3_1 = HBox([p1box,p2_1])
box3_2 = VBox([box3_1, accordionp])
box3_2.layout = Layout(border="solid 5px lightblue", margin="10px", padding="10px", width = "750px", height = "500px")
box3_1.children[0].layout = Layout(padding="5px 30px 5px 0px", width = "265px")
box3_1.children[1].layout = Layout(margin="5px 20px 5px 0px")

############################# Box 3_3 = One sample Proportion ###################################################################
#######Set effect sizes for one sample proportion
pglobal= -0.2
Pglobal = -0.2
nglobal = -0.2

def values(p, P, sampsize):
    global pglobal
    global Pglobal
    global nglobal
    if p == "":
        print(Fore.RED + "Warnning: Please define the proportions above")
    if p != "" and sampsize !="":
        pglobal =float(p); Pglobal = float(P); nglobal = int(sampsize)
        pdifference = abs((float(p)) - (float(P)));
        numerator = float(P) * (1 - float(P));
        SE = np.sqrt(numerator / int(sampsize))
        Z_score = pdifference / SE
        d = abs((Z_score / np.sqrt(int(sampsize))))
        pval = min((stats.t.sf((abs(Z_score)), 100000)*2), 0.99999)
        print(Fore.GREEN + "Parameters were succesfully loaded\n", Fore.BLUE + f"Your p.value = {round(pval,7)}\n Now choose one or more effect sizes from below")
    if p != "" and sampsize =="":
        print(Fore.GREEN + "Parameters were succesfully loaded", Fore.BLUE + "If You Want the p.value as well, define the sample size.", Fore.GREEN + "You can now calculate one or more effect sizes from below")
        pglobal = float(p)
        Pglobal = float(P)
        nglobal = int(sampsize)

def p31():
    p301 = float(pglobal)
    if pglobal > -0.2:
        cohensg = abs(p301 - 0.5)
        print(f"Cohens g = {round(cohensg,7)}")
    if pglobal == -0.2:
        print(Fore.RED + "Warnning: Please define the proportions above")

def p32():
    p302 = float(pglobal)
    P302 = float(Pglobal)
    if pglobal > -0.2:
        RR = p302/P302
        print(f"Risk Ratio = {round(RR,7)}")
    if pglobal == -0.2:
        print(Fore.RED + "Warnning: Please define the proportions above")
        
def p33():
    p303 = float(pglobal)
    P303 = float(Pglobal)
    if pglobal > -0.2:
        OR = (p303/(1-p303)) / (P303/(1-P303))
        print(f"Odds Ratio = {round(OR,7)}")
    if pglobal == -0.2:
        print(Fore.RED + "Warnning: Please define the proportions above")
        
def p34():
    p304 = float(pglobal)
    P304 = float(Pglobal)
    n = int(nglobal)
    if pglobal > -0.2:
        pi = (p304*(n+1)) / (p304*(n*2)+1)
        print(f"Proprtion of hits (Π) = {round(pi,7)}")
    if pglobal == -0.2:
        print(Fore.RED + "Warnning: Please define the proportions above")

###Creating Box3_3
style = {'description_width': 'initial'}
p3 = interactive(values,{'manual': True}, p="", P="", sampsize="")
p3_1 = interactive(p31, {'manual': True} )
p3_2 = interactive(p32, {'manual': True} )
p3_3 = interactive(p33, {'manual': True} )
p3_4 = interactive(p34, {'manual': True} )

####Styling
p3.children[0].layout = Layout(width='150px', padding = "5px 20px 10px 0px")
p3.children[1].layout = Layout(width='180px', padding = "5px 20px 10px 0px")
p3.children[2].layout = Layout(width='150px', padding = "5px 20px 10px 0px")
p3.children[0].description = "<b>p Sample</b>"
p3.children[1].description = "<b>P Population</b>"
p3.children[2].description = "<b> Sample Size </b>"
p3.children[0].style = style
p3.children[1].style = style
p3.children[2].style = style
p3.children[3].style = style
p3.children[3].style.button_color = "darksalmon"
p3.children[3].description = "Click Here to Load Values Before Calculation"
p3.children[3].style.font_weight = "bold"; p3.children[3].layout = Layout(width='300px')
p3_1.children[0].style.button_color = "lightblue"
p3_1.children[0].description = "Calculate Cohens g When P=0.5"
p3_1.children[0].style.font_weight = "bold"
p3_1.children[0].layout = Layout(width='250px')
p3_2.children[0].style.button_color = "lightblue";
p3_2.children[0].description = "Calculate Risk Ratio";
p3_2.children[0].style.font_weight = "bold";
p3_2.children[0].layout = Layout(width='250px')
p3_3.children[0].style.button_color = "lightblue";
p3_3.children[0].description = "Calculate Odds Ratio";
p3_3.children[0].style.font_weight = "bold";
p3_3.children[0].layout = Layout(width='250px')
p3_4.children[0].style.button_color = "lightblue";
p3_4.children[0].description = "Calculate Π for proportion of hits";
p3_4.children[0].style.font_weight = "bold";
p3_4.children[0].layout = Layout(width='250px')

controls31 = VBox([
          HBox([p3.children[0],p3.children[1],p3.children[2]]),
          HBox([p3.children[3]]),])
output31 = p3.children[-1]

controls32 = VBox([
          HBox([p3_1.children[0],p3_4.children[0]]),
          HBox([p3_3.children[0],p3_2.children[0]]),])
output321 = p3_1.children[-1]
output322 = p3_2.children[-1]
output323 = p3_3.children[-1]
output324 = p3_4.children[-1]
          
box3_3 = VBox([pbox3,controls31, output31, controls32, output321,output322, output323, output324])
box3_3.layout = Layout(border="solid 5px lightblue", padding="5px 10px 0px 10px", margin="10px", width = "650px", height = "500px")
box3_3.children[0].layout = Layout(padding="0px 0px 30px 0px", width = "auto", height = "auto")
#p3.children[0].layout = Layout(padding="0px 0px 30px 0px", width = "auto", height = "auto")
#p3.children[1].layout = Layout(padding="0px 0px 30px 0px", width = "auto", height = "auto")

################################################ Box3 Final ####################################################################
box3 = HBox([box3_2, box3_3])
box3.layout = Layout(border="solid 2px lightcoral", margin="0px 0px 50px 0px", padding="10px", width = "1200px", height = "555px")
box3_3.children[0].layout = Layout(margin="8px 10px 0px 10px", padding="8px 10px 0px 10px")

#################################################################################################################################

###########################################################################################################################
##############################################   Two Independent means   ##################################################
########                                                                                                            #######
###########################################################################################################################                                                                                                            
###########################################################################################################################

#headers
hbox4_1 = widgets.HTML(value= '<p style = "word-wrap: break-word; color: black; font-size: 140%; text-align: center;" > <b><u> Population Effect Size </u></b> </p>')
hbox4_2 = widgets.HTML(value= '<p style = "word-wrap: break-word; color: black; font-size: 140%; text-align: center;" > <b><u> Estimated/Unbaised Effect Size </u></b> </p>')
hbox4_3 = widgets.HTML(value= '<style>p{word-wrap: break-word; color: black; font-size: 140%; text-align: center}</style> <p> <b><u> "From t to Effect size"<u></b> </p>')
hbox4_4 = widgets.HTML(value= '<p style = "word-wrap: break-word; color: black; font-size: 140%; text-align: center;" > <b><u> Other Effect Sizes </u></b> </p>')
###########################################################################################################################

############################# Box 4_1 = Population difference ###################################################################
def Z_test2(MeaS1, MeaS2, Si1, Si2, MeaP):
    if any(i.isalpha() for i in MeaS1) != True and any(i.isalpha() for i in MeaS2) !=True and any(i.isalpha() for i in Si1) !=True and Si1>"0" and any(i.isalpha() for i in Si2) !=True and Si2>"0" and "," not in Si1 and "," not in MeaS1 and "," not in MeaS2 and "," not in Si2 and (MeaS1 and Si1 and Si2 and MeaS2) !="":
        MeaP = float(MeaP); MeaS1 = float(MeaS1); MeaS2 = float(MeaS2); Si1 = float(Si1)**2; Si2 = float(Si2)**2;  
        diff = abs(MeaP - (MeaS1 - MeaS2))
        d = diff/(np.sqrt((Si1 +Si2)/2))
        print(f"Population Cohens d = {round(d,7)}")
    elif MeaS1 == "":
        print(Fore.RED + "Please define the means above")
    elif MeaS2 == "":
        print(Fore.RED + "Please define the means above")
    elif Si1 == "":
        print(Fore.RED + "Please define SD1 above")
    elif Si2 == "":
        print(Fore.RED + "Please define SD2 above")
    else:
        print(Fore.YELLOW + Back.RED + "Warnning!!! You have just entered an illegal character")

style = {'description_width': 'initial'}    
Z2 = interactive(Z_test2, {'manual': True},MeaS1 = "", MeaS2 = "", Si1 = "", Si2 = "", MeaP="0")
Z2.children[0].layout = Layout(width='200px', padding = "0px 25px 0px 0px")
Z2.children[1].layout = Layout(width='200px')
Z2.children[2].layout = Layout(width='200px', padding = "0px 25px 0px 0px")
Z2.children[3].layout = Layout(width='200px')
Z2.children[4].layout = Layout(width='300px')
Z2.children[0].style = style
Z2.children[1].style = style
Z2.children[2].style = style
Z2.children[3].style = style
Z2.children[4].style = style
Z2.children[0].description = "<b> Population1 Mean </b>" 
Z2.children[1].description = "<b> Population2 Mean </b>"
Z2.children[2].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;"> Population1 SD </span> <span style="color: white;">.__</span> </p>'
Z2.children[3].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;"> Population2 SD </span> <span style="color: white;">_._</span> </p>'
Z2.children[4].description = "<b> Difference in the population </b>"
Z2.children[5].style.button_color="lightblue"
Z2.children[5].description="Calculate Populations Cohen's d" 
Z2.children[5].style.font_weight = "bold"
Z2.children[5].layout = Layout(width='250px')


accordionind = widgets.Accordion(children=[
    widgets.HTML(value= '<style>p{word-wrap: break-word}</style> <p>' "now i can write here whatever i want on hedges and check if there is a text wrapping or not"' </p>'),
    widgets.HTML(value= '<style>p{word-wrap: break-word}</style> <p>' "now i can write here whatever i want on hedges and check if there is a text wrapping or not" +' </p>'),
    widgets.HTML(value= '<style>p{word-wrap: break-word}</style> <p>' "now i can write here whatever i want on hedges and check if there is a text wrapping or not" +' </p>'),
    widgets.HTML(value= '<style>p{word-wrap: break-word}</style> <p>' "now i can write here whatever i want on hedges and check if there is a text wrapping or not" +' </p>'),
    widgets.HTML(value= '<style>p{word-wrap: break-word}</style> <p>' "now i can write here whatever i want on hedges and check if there is a text wrapping or not" +' </p>'),
    widgets.HTML(value= '<style>p{word-wrap: break-word}</style> <p>' "now i can write here whatever i want on hedges and check if there is a text wrapping or not" +' </p>'),
    widgets.HTML(value= '<style>p{word-wrap: break-word}</style> <p>' " </p> <b> <u>The Population corrected Effect Size </u></b> <p> In some cases the variances are not assumed to be equal. In this case there is no consensus which of the effect sizes is most suitable. Delacre et al. Suggested that the popoulation effect size that Cohen (1988) suggested for unequal variances (d*<sub>s</sub> as they call it) should be corrected with the Hedges` correction and used as the effect size in such a case. They call this new effect size (Hedges' g*<sub>s</sub>, i n this is how we will refer it here. </p> <br> <p>Another effect size - the epsilon (Aoki, 2020) makes an adaptation for a case where the Welch test is used based on the paramaters of the Welch test for indpendent samples with unequal variances (You can check out the formula of this unbaised effect size in the formula box below)" +' </p>'),
    widgets.HTML(value= '<style>p{word-wrap: break-word}</style> <p>' "Following Kulinskaya and Staudte (2007) suggestion, Shieh (2013) suggested an SD estimate which takes into consideration the allocation ratio of the samples (see the formula in the formulae section), However, when using this effect size you have to consider Cumming(2013) criticism for using this as a measure " +' </p>'),
    widgets.Image(value=image7,format='png',width=500,height=400,),
    widgets.Image(value=image7,format='png',width=500,height=400,),],)
accordionind.set_title(0, 'Click Here for an introduction')
accordionind.set_title(1, "More about Hedges' g? Click here")
accordionind.set_title(2, "More about Glass' Delta? Click here") 
accordionind.set_title(3, 'More about MLE? Click here')
accordionind.set_title(4, 'More about Common Language Effect Size? Click here')
accordionind.set_title(5, 'More about Robust effect size (S)? Click here')
accordionind.set_title(6, 'Effect sizes with unequal variances (Hedges g* & Epsilon')
accordionind.set_title(7, 'Shieh - An effec size for unbalanced sample sizes')
accordionind.set_title(8, 'Click here to see all the formulae')
accordionind.set_title(9, 'Babilonian of Effect Sizes')
accordionind.selected_index = None

controls41 = VBox([HBox([Z2.children[0],Z2.children[1]]),
                   HBox([Z2.children[2],Z2.children[3]]),
                   HBox([Z2.children[4]]),
                   HBox([Z2.children[5]])])
output41 = Z2.children[-1]

box41 = VBox([controls41, output41, accordionind])
box41.layout = Layout(border="solid 5px lightblue", margin="10px 2px 2px 0px", padding="5px", width = "460px", height = "730px")
box4_1 = VBox([hbox4_1, box41])
###########################################################################################################################

############################# Box 4_2  = t-test for the difference###################################################################
##### From Parameters to effect Size
def t_test2(MeanS1, MeanS2, Sig1, Sig2, sampsize1, sampsize2, MeanP):
    if any(i.isalpha() for i in MeanS1) != True and any(i.isalpha() for i in MeanS2) !=True and any(i.isalpha() for i in Sig1) !=True and Sig1>"0" and any(i.isalpha() for i in Sig2) !=True and Sig2>"0" and sampsize1.isdigit()==True and sampsize2.isdigit()==True and "," not in Sig1 and "," not in MeanS1 and "," not in MeanS2 and "," not in Sig2 and (MeanS1 and Sig1 and Sig2 and MeanS2 and sampsize1 and sampsize2) !="":
      MeanP = float(MeanP); MeanS1 = float(MeanS1); MeanS2 = float(MeanS2); Sig1 = float(Sig1); Sig2 = float(Sig2); n1 = float(sampsize1); n2 = float(sampsize2);  
      df1 = n1-1
      df2 = n2-1
      df = df1+df2
      diff = (MeanS1-MeanS2)
      spooled = np.sqrt( ((((Sig1**2)*df1) + ((Sig2**2)*df2)) /df))
      correction = np.sqrt(1/n1+1/n2)
      SE = spooled*correction
      numer = ((Sig1**2)*df1)+((Sig2**2)*df2)
      denom = df1+df2
      SD = np.sqrt(numer/denom)
      d = abs(diff/SD) 
      g = d * (((n1+n2) - 3) / ((n1+n2)-2.25))
      t = abs(diff/SE)
      pval = min(((stats.t.sf((abs(t)), (n1+n2-2)))*2), 0.99999)

      print(f"t-score = {round(t,7)}\np-value(2-tailed) = {round(pval,7)}\nCohen's d = {round(d,7)}\nHedges g = {round(g,7)}")
    elif MeanS1 == "":
      print(Fore.RED + "Please define mean1 above")
    elif MeanS2 == "":
      print(Fore.RED + "Please define mean2 above")
    elif Sig1 == "":
      print(Fore.RED + "Please define SD1 above")
    elif Sig2 == "":
      print(Fore.RED + "Please define SD2 above")
    elif sampsize1 == "":
      print(Fore.RED + "Please define Sample1 size")
    elif sampsize2 == "":
      print(Fore.RED + "Please define Sample2 size")
    else:
      print(Fore.YELLOW + Back.RED + "Warnning!!! You have just entered an illegal character")

#Styling
style = {'description_width': 'initial'}    
T2 = interactive(t_test2, {'manual': True},MeanS1 = "", MeanS2 = "", Sig1 = "", Sig2 = "", sampsize1 = "", sampsize2 = "", MeanP="0")
T2.children[0].layout = Layout(width='194px', padding = "0px 21px 0px 0px")
T2.children[1].layout = Layout(width='185px') 
T2.children[2].layout = Layout(width='193px', padding = "0px 20px 0px 0px")
T2.children[3].layout = Layout(width='186px')
T2.children[4].layout = Layout(width='193.2px', padding = "0px 20px 0px 0px")
T2.children[5].layout = Layout(width='186px') 
T2.children[6].layout = Layout(width='250px')
T2.children[0].style = style 
T2.children[1].style = style 
T2.children[2].style = style 
T2.children[3].style = style
T2.children[4].style = style
T2.children[5].style = style
T2.children[6].style = style
T2.children[0].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;"> Sample1 Mean </span> <span style="color: white;">.</span> </p>' 
T2.children[1].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;"> Sample2 Mean </span> <span style="color: white;"></span> </p>'
T2.children[2].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;"> Sample1 SD </span> <span style="color: white;">_.__</span> </p>'
T2.children[3].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;"> Sample2 SD </span> <span style="color: white;">___</span> </p>' 
T2.children[4].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;"> Sample1 N </span> <span style="color: white;">_____</span> </p>' 
T2.children[5].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;"> Sample2 N </span> <span style="color: white;">......</span> </p>'
T2.children[6].description = " <b>*Difference In the Population </b>";


T2.children[7].style.button_color="lightblue"
T2.children[7].description="Estimated Cohen's d + Hedges` g";
T2.children[7].style.font_weight = "bold" 
T2.children[7].layout = Layout(width='250px')

##### From T to effect Size
def t_test3(T3_score, SampleN1,SampleN2):
    if (any(i.isalpha() for i in T3_score)) !=True and SampleN2.isdigit() == True and SampleN1.isdigit() == True and (",") not in T3_score:
        T3_score = float(T3_score); SampleN1 = float(SampleN1); SampleN2 = float(SampleN2)
        pval = min(((stats.t.sf((abs(T3_score)), (SampleN1+SampleN2-2)))*2), 0.99999)
        SE1 = np.sqrt((1/SampleN1)+(1/SampleN2))
        d = abs(T3_score * SE1)
        g = abs(d * (((SampleN1+SampleN2) - 3) / ((SampleN1+SampleN2)-2.25)))
        print(f"p-value(2-tailed) = {round(pval,7)}\nCohen's d = {round(d,7)}\nHedges` g = {round(g,7)}")
    elif T3_score == "":
         print(Fore.RED + "Please define t-score")
    elif SampleN1 == "":
         print(Fore.RED + "Please define Sample1 size")
    elif SampleN2 == "":
         print(Fore.RED + "Please define Sample2 size")
    else:
         print(Fore.YELLOW + Back.RED + "Warnning!!! You have just entered an illegal character")

style = {'description_width': 'initial'}    
t3 = interactive(t_test3, {'manual': True}, T3_score="", SampleN1 = "", SampleN2 = "")
t3.children[0].layout = Layout(width='150px', margin = "0px 0px 10px 0px")
t3.children[1].layout = Layout(width='170px', margin = "0px 30px 0px 0px") 
t3.children[2].layout = Layout(width='160px') 
t3.children[0].description = "<b>t Score </b>"
t3.children[1].description = "<b>Sample Size 1 </b>" 
t3.children[2].description = "<b>Sample Size 2 </b>"
t3.children[0].style = style
t3.children[1].style = style 
t3.children[2].style = style 
t3.children[3].style.button_color="lightblue" 
t3.children[3].description="Estimated Cohen's d + Hedges` g"
t3.children[3].style.font_weight = "bold"
t3.children[3].layout = Layout(width='250px')

controls2 = VBox([HBox([T2.children[0],T2.children[1]]),
                  HBox([T2.children[2],T2.children[3]]),
                  HBox([T2.children[4],T2.children[5]]),
                  HBox([T2.children[6]]),
                  HBox([T2.children[7]])])
output2 = T2.children[-1]

controls3 = VBox([HBox([t3.children[0]]),
          HBox([t3.children[1],t3.children[2]]),
          HBox([t3.children[3]])])
output3 = t3.children[-1]

bes = widgets.Image(value=image8,format='png',width="150px",height="150px",)

box4_21 = VBox([controls2,output2,bes, hbox4_3,controls3, output3])
box4_21.layout = Layout(border="solid 5px lightblue", padding="10px", margin="10px 10px 0px 10px", width = "420px", height = "695px")
box4_21.children[2].layout = Layout(padding="0px 0px 0px 0px", margin ="0px 30px 0px 70px",)
box4_21.children[3].layout = Layout(padding="0px 0px 0px 0px", margin ="30px 0px 0px 0px",)


###########################################################################################################################
box4_2 = VBox([hbox4_2, box4_21])

###########################################################################################################################


############################# Box 4_3  = Other Effect Sizes  ###################################################################
MeanPglobal=0; MeanS1global=-2; MeanS2global=-2; Sig1global=-2; Sig2global=-2; sampsize1global=-2; sampsize2global=-2;
def t_test4(MeanS1, MeanS2, Sig1, Sig2, sampsize1, sampsize2, MeanP):
    if any(i.isalpha() for i in MeanS1) != True and any(i.isalpha() for i in MeanS2) !=True and any(i.isalpha() for i in Sig1) !=True and Sig1>"0" and any(i.isalpha() for i in Sig2) !=True and Sig2>"0" and sampsize1.isdigit()==True and sampsize2.isdigit()==True and "," not in Sig1 and "," not in MeanS1 and "," not in MeanS2 and "," not in Sig2 and (MeanS1 and Sig1 and Sig2 and MeanS2 and sampsize1 and sampsize2) !="":
        global MeanPglobal; global MeanS1global; global MeanS2global;global Sig1global;global Sig2global; global sampsize1global; global sampsize2global;
        MeanP = float(MeanP); MeanS1 = float(MeanS1); MeanS2 = float(MeanS2); Sig1 = float(Sig1); Sig2 = float(Sig2); n1 = float(sampsize1); n2 = float(sampsize2);  
        MeanS1global =float(MeanS1)
        MeanS2global = float(MeanS2)
        diff = abs(MeanS1 - MeanS2);
        difference = abs(MeanP - diff)
        df = n1 + n2-2
        df1 = n1-1
        df2 = n2-1
        SEnumerator = (df1*(Sig1**2)) + (df2*(Sig2**2))
        SE = (np.sqrt(SEnumerator/df)) * (np.sqrt((n1+n2)/(n1*n2)))
        t3_score = difference / SE
        pval = min((stats.t.sf((abs(t3_score)), df)*2), 0.99999)
        MeanPglobal = float(MeanP)
        MeanS1global = float(MeanS1)
        MeanS2global = float(MeanS2)
        Sig1global = float(Sig1)
        Sig2global = float(Sig2)
        sampsize1global = float(sampsize1)
        sampsize2global = float(sampsize2)
        print(Fore.GREEN + "✔ Parameters were loaded\n", Fore.BLUE + f"Your p.value(2-tailed) = {round(pval,7)}\n Now choose your Effect Size")   
    elif MeanS1 == "":
        print(Fore.RED + "Please define Mean1 above")
    elif MeanS2 == "":
        print(Fore.RED + "Please define Mean2 above")
    elif Sig2 == "":
        print(Fore.RED + "Please define SD1 above")
    elif Sig1 == "":
        print(Fore.RED + "Please define SD2 above")
    elif sampsize1 == "":
        print(Fore.RED + "Please define Sample1 size")
    elif sampsize2 == "":
        print(Fore.RED + "Please define Sample2 size")
    else:
        print(Fore.YELLOW + Back.RED + "Warnning!!! You have just entered an illegal character")

def t41():
    t401 = float(MeanS1global)
    t402 = float(MeanS2global)
    t403 = float(Sig1global)
    if Sig1global > -2:
        Delta = (abs(t402-t401))/(t403)
        print(f"Glass' Δ = {round(Delta,7)}")
    if Sig1global == -2:
        print(Fore.RED + "Please define values above")

def t42():
    t421 = float(MeanS1global)
    t422 = float(MeanS2global)
    t423 = float(Sig1global)
    t424 = float(Sig2global)
    t425 = float(sampsize1global)
    t426 = float(sampsize2global)
    if Sig1global > -2:
        df1 = t425-1
        df2 = t426-1
        var1 = t423**2
        var2 = t424**2
        numerator = df1*var1+df2*var2
        SD = np.sqrt(numerator/(t425+t426))
        diff = abs(t421-t422)
        d = diff/SD
        print(f"MLE Effect Size = {round(d,7)}")
    if Sig1global == -2:
        print(Fore.RED + "Please define values above")
        
def t43():
    t431 = float(MeanS1global)
    t432 = float(MeanS2global)
    t433 = float(Sig1global)
    t434 = float(Sig2global)
    if Sig1global > -2:
        diff = abs(t431-t432)
        SD = np.sqrt((t433**2 +t434**2))
        Z = diff/SD
        d1 = stats.norm.sf(abs(Z))
        d2 = 1-(stats.norm.sf(abs(Z)))
        CLES = max(d1,d2) 
        print(f"CLES = {round(CLES,7)}")
    if Sig1global == -2:
        print(Fore.RED + "Please define values above")

def t44():
    t441 = float(MeanS1global)
    t442 = float(MeanS2global)
    t443 = float(Sig1global)
    t444 = float(Sig2global)
    t445 = float(sampsize1global)
    t446 = float(sampsize2global)    
    if Sig1global > -2:
        pi1 = (t445/(t445+t446))
        pi2 = 1-pi1
        var1 = (t443**2)*(1/pi1)
        var2 = t444**2*(1/pi2)
        denom = var1+var2
        diff = (t441-t442)**2
        d = np.sqrt((diff/denom))
        print(f"Robust Effect Size (S) = {round(d,7)}")
    if Sig1global == -2:
        print(Fore.RED + "Please define values above")

def t45():
    t451 = float(MeanS1global)
    t452 = float(MeanS2global)
    t453 = float(Sig1global)
    t454 = float(Sig2global)
    t455 = float(sampsize1global)
    t456 = float(sampsize2global)    
    if Sig1global > -2:
        #Hedges g*
        diff = abs(t451-t452)
        sdaverage = np.sqrt((((t453**2)+(t454**2))/2))
        popd = diff/sdaverage
        correction = 1 - abs(3/(4*(t455+t456-2)-1))
        popg = popd*correction
        
        # Epsilon
        var1 = t453**2
        var2 = t454**2
        n41 = t455**2
        n42 = t456**2
        n = t455*t456/(t455+t456)
        var3 = t453**4
        var4 = t454**4
        denom = np.sqrt(t453**2/t455+(t454**2/t456))
        tw = diff/denom
        epsilonbiased = tw/np.sqrt(n)
        numer = ((var1/t455)+(var2/t456))**2
        denom2 = (var3/((n41)*(t455-1))) + (var4/(n42*(t456-1)))
        df = numer/denom2
        numer3 = math.gamma(df/2)
        denom31 = np.sqrt(df/2)
        denom32 = math.gamma((df-1)/2)
        denom3 = denom31*denom32
        j = numer3/denom3
        e = epsilonbiased*j
        print(f"Unbiased ε = {round(e,7)}\n Hedges g* = {round(popg,7)}")
def t46():
    t461 = float(MeanS1global)
    t462 = float(MeanS2global)
    t463 = float(Sig1global)
    t464 = float(Sig2global)
    t465 = float(sampsize1global)
    t466 = float(sampsize2global)    
    if Sig1global > -2:
        #Hedges g*
        diff = abs(t461-t462)
        q1 = t465/(t465+t466)
        q2 = 1 - q1
        Varatio1 = (t463**2)/q1
        Varatio2 = (t464**2)/q2
        spooled = np.sqrt((Varatio1 + Varatio2))
        shieh = diff/spooled
        correction = 1 - abs(3/(4*(t465+t466-2)-1))
        shiehg = shieh*correction
        print(f"Shieh d= {round(shieh,7)}\nShieh g = {round(shiehg,7)}")
    if Sig1global == -2:
        print(Fore.RED + "Please define values above")

#Styling
style = {'description_width': 'initial'}    
T4 = interactive(t_test4, {'manual': True},MeanS1 = "", MeanS2 = "", Sig1 = "", Sig2 = "", sampsize1 = "", sampsize2 = "",MeanP="0")
t4_1 = interactive(t41, {'manual': True} )
t4_2 = interactive(t42, {'manual': True} )
t4_3 = interactive(t43, {'manual': True} )
t4_4 = interactive(t44, {'manual': True} )
t4_5 = interactive(t45, {'manual': True} )
t4_6 = interactive(t46, {'manual': True} )

T4.children[0].layout = Layout(width='158px', margin = "0px 19px 0px 0px")
T4.children[1].layout = Layout(width='158px') 
T4.children[2].layout = Layout(width='158px', margin = "0px 19px 0px 0px")
T4.children[3].layout = Layout(width='158px')
T4.children[4].layout = Layout(width='158px', margin = "0px 19px 0px 0px") 
T4.children[5].layout = Layout(width='158px') 
T4.children[6].layout = Layout(width='300px')
T4.children[0].style = style;
T4.children[1].style = style
T4.children[2].style = style
T4.children[3].style = style
T4.children[4].style = style
T4.children[5].style = style
T4.children[6].style = style
T4.children[0].description = "<b> Sample1 Mean </b>" 
T4.children[1].description = "<b> Sample2 Mean </b>"
T4.children[2].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;"> Sample1 SD </span> <span style="color: white;">_._</span> </p>'
T4.children[3].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;"> Sample2 SD </span> <span style="color: white;">_._</span> </p>'
T4.children[4].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;"> Sample1 N </span> <span style="color: white;">____</span> </p>'  
T4.children[5].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;"> Sample2 N </span> <span style="color: white;">____</span> </p>'
T4.children[6].description = " <b> *Difference In the Population </b>"
T4.children[7].style.button_color="darksalmon"
T4.children[7].description="Click Here to load Values"
T4.children[7].style.font_weight = "bold" 
T4.children[7].layout = Layout(width='300px', height="auto")

controls4 = VBox([
          HBox([T4.children[0],T4.children[1]]),
          HBox([T4.children[2],T4.children[3]]),
          HBox([T4.children[4],T4.children[5]]),
          HBox([T4.children[6]]),
          HBox([T4.children[7]])])

output4 = T4.children[-1]

t4_1.children[0].style.button_color = "lightblue";
t4_1.children[0].description = "Glass' Delta (Sample1 = Control)";
t4_1.children[0].style.font_weight = "bold"; 
t4_1.children[0].layout = Layout(width='310px')
t4_2.children[0].style.button_color = "lightblue";
t4_2.children[0].description = "Maximum Likelihood Estimation (MLE)";
t4_2.children[0].style.font_weight = "bold";
t4_2.children[0].layout = Layout(width='310px')
t4_3.children[0].style.button_color = "lightblue";
t4_3.children[0].description = "Common Language Effect Size" 
t4_3.children[0].style.font_weight = "bold";
t4_3.children[0].layout = Layout(width='310px')
t4_4.children[0].style.button_color = "lightblue";
t4_4.children[0].description = "Robust Effect Size (S)"
t4_4.children[0].style.font_weight = "bold"; 
t4_4.children[0].layout = Layout(width='310px')
t4_5.children[0].style.button_color = "lightblue";
t4_5.children[0].description = "Unequal SD's effect sizes Epsilon + Hedges' g*"; 
t4_5.children[0].style.font_weight = "bold"; 
t4_5.children[0].layout = Layout(width='310px')
t4_6.children[0].style.button_color = "lightblue"; 
t4_6.children[0].description = "Unequal Sample Size effect sizes - Shieh"; 
t4_6.children[0].style.font_weight = "bold"; 
t4_6.children[0].layout = Layout(width='310px')

##############################################################################################################################
box4_3 = VBox([controls4, output4, t4_1, t4_2, t4_3, t4_4, t4_5, t4_6])
box4_3.children[0].layout = Layout(padding="0px", margin ="0px 0px 0px 0px", width = "auto", height = "auto")
box4_3.layout = Layout(padding="10px", margin ="10px 0px 0px 0px", width = "auto", height = "auto")
box4_3.layout = Layout(border="solid 5px lightblue", padding="10px", margin="10px 5px 0px 0px", width = "370px", height = "690px")
box4_3.children[0].layout = Layout(padding="0px 0px 0px 0px", width = "auto", height = "160px")
box4_3.children[1].layout = Layout(padding="0px 0px 5px 0px", width = "auto", height = "auto")
box4_3.children[2].layout = Layout(padding="0px 0px 5px 0px", width = "auto", height = "auto")
box4_3.children[3].layout = Layout(padding="0px 0px 5px 0px", width = "auto", height = "auto")
box4_3.children[4].layout = Layout(padding="0px 0px 5px 0px", width = "auto", height = "auto")
box4_3.children[5].layout = Layout(padding="0px 0px 5px 0px", width = "auto", height = "auto")
box4_3.children[6].layout = Layout(padding="0px 0px 5px 0px", width = "auto", height = "auto")

box4_3 = VBox([hbox4_4,box4_3])

###########################################################################################################################
box4 = HBox([box4_1, box4_2, box4_3])
box4.layout = Layout(border="solid 2px indianred", padding="10px", margin="10px 5px 0px 0px", width = "1300px", height = "755px")

###########################################################################################################################

#################################################################################################################################

###########################################################################################################################
##############################################   Two Dependent means   ##################################################
########                                                                                                            #######
###########################################################################################################################                                                                                                            
###########################################################################################################################

#headers
hbox5_1 = widgets.HTML(value= '<p style = "word-wrap: break-word; color: black; font-size: 140%; text-align: center;" > <b><u> Effect Size dz from the difference (One Sample) </u></b> </p>')
hbox5_2 = widgets.HTML(value= '<style>p{word-wrap: break-word; color: black; font-size: 140%; text-align: center}</style> <p> <b><u> "From t to Effect size"<u></b> </p>')
hbox5_3 = widgets.HTML(value= '<p style = "word-wrap: break-word; color: black; font-size: 140%; text-align: center;" > <b><u> All Effect Sizes from correlation of measures </u></b> </p>')
###########################################################################################################################

############################# Box 5_1 = Basic Effect Sizes ###################################################################
def t_test51(Diffs, Sigd, n, Diffp):
    if any(i.isalpha() for i in Diffs) != True and any(i.isalpha() for i in Sigd) !=True and any(i.isdigit() for i in n) ==True and Sigd>"0" and "," not in Sigd and "," not in Diffp and "," not in Diffs and "," not in n and (Sigd and Diffp and Diffs and n) !="":
        Diffp = float(Diffp); Diffs = float(Diffs); Sigd = float(Sigd); n = float(n); 
        df = n-1
        SE = Sigd/np.sqrt(n)
        difference = abs(Diffs - Diffp)
        cohensd = abs((difference/Sigd))
        t5 = difference/SE
        pval = min(((stats.t.sf((abs(t5)), (df)))*2), 0.99999)
        print(f"p-value(2-tailed)= {round(pval,7)}\nCohen's d = {round(cohensd,7)}, t = {round(t5,7)} \nStandart Error= {round(SE,7)}")
    elif Diffs == "":
        print(Fore.RED + "Please define the mean difference above")
    elif Sigd == "":
        print(Fore.RED + "Please define the SD of the difference above")
    elif n == "":
        print(Fore.RED + "Please define N above")
    else:
        print(Fore.YELLOW + Back.RED + "Warnning!!! You have just entered an illegal character")

style = {'description_width': 'initial'}    
T51 = interactive(t_test51, {'manual': True},Diffs = "", Sigd = "", n = "", Diffp="0")
T51.children[0].layout = Layout(width='145px', padding = "0px 5px 0px 0px")
T51.children[1].layout = Layout(width='157px', padding = "0px 5px 0px 0px")
T51.children[2].layout = Layout(width='126px', padding = "0px 5px 0px 0px")
T51.children[3].layout = Layout(width='280px')
T51.children[0].style = style
T51.children[1].style = style
T51.children[2].style = style
T51.children[3].style = style
T51.children[0].description = "<b> Difference (d) </b>" 
T51.children[1].description = "<b> SD of difference </b>"
T51.children[2].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;"> Sample Size </span> <span style="color: white;"></span> </p>'
T51.children[3].description = "<b> *Difference in the population </b>"
T51.children[4].style.button_color="lightblue"
T51.children[4].description="Calculate Cohen's dz and Hedges' gz" 
T51.children[4].style.font_weight = "bold"
T51.children[4].layout = Layout(width='250px')


accordionind = widgets.Accordion(children=[
    widgets.HTML(value= '<style>p{word-wrap: break-word}</style> <p>' "now i can write here whatever i want on hedges and check if there is a text wrapping or not"' </p>'),
    widgets.HTML(value= '<style>p{word-wrap: break-word}</style> <p>' "now i can write here whatever i want on hedges and check if there is a text wrapping or not" +' </p>'),
    widgets.HTML(value= '<style>p{word-wrap: break-word}</style> <p>' "now i can write here whatever i want on hedges and check if there is a text wrapping or not" +' </p>'),
    widgets.Image(value=image7,format='png',width=500,height=400,),],)
accordionind.set_title(0, 'Click Here for an introduction')
accordionind.set_title(1, "More about Hedges' g? Click here")
accordionind.set_title(2, "More about Glass' Delta? Click here") 
accordionind.set_title(3, 'Click here to see all the formulae')
accordionind.selected_index = None

controls51 = VBox([HBox([T51.children[0],T51.children[1],T51.children[2]]),
                   HBox([T51.children[3]]),
                   HBox([T51.children[4]]),])
output51 = T51.children[-1]


def t_test52(T2_score, SampleN1,SampleN2):
    if (any(i.isalpha() for i in T3_score)) !=True and SampleN2.isdigit() == True and SampleN1.isdigit() == True and (",") not in T3_score:
        T3_score = float(T2_score); SampleN1 = float(SampleN1); SampleN2 = float(SampleN2)
        pval = min(((stats.t.sf((abs(T3_score)), (SampleN1+SampleN2-2)))*2), 0.99999)
        SE = np.sqrt((1/SampleN1)+(1/SampleN2))
        d = abs(T2_score * SE)
        g = abs(d * (((SampleN1+SampleN2) - 3) / ((SampleN1+SampleN2)-2.25)))
        print(f"p-value(2-tailed) = {round(pval,7)}\nCohen's d = {round(d,7)}\nHedges` g = {round(g,7)}")
    elif T2_score == "":
         print(Fore.RED + "Please define t-score")
    elif SampleN1 == "":
         print(Fore.RED + "Please define Sample1 size")
    elif SampleN2 == "":
         print(Fore.RED + "Please define Sample2 size")
    else:
         print(Fore.YELLOW + Back.RED + "Warnning!!! You have just entered an illegal character")

style = {'description_width': 'initial'}    
t52 = interactive(t_test52, {'manual': True}, T2_score="", SampleN1 = "", SampleN2 = "")
t52.children[0].layout = Layout(width='150px', margin = "0px 0px 10px 0px")
t52.children[1].layout = Layout(width='170px', margin = "0px 30px 0px 0px") 
t52.children[2].layout = Layout(width='160px') 
t52.children[0].description = "<b>t Score </b>"
t52.children[1].description = "<b>Sample Size 1 </b>" 
t52.children[2].description = "<b>Sample Size 2 </b>"
t52.children[0].style = style
t52.children[1].style = style 
t52.children[2].style = style 
t52.children[3].style.button_color="lightblue" 
t52.children[3].description="Estimated Cohen's d + Hedges` g"
t52.children[3].style.font_weight = "bold"
t52.children[3].layout = Layout(width='250px')

controls52 = VBox([HBox([t52.children[0]]),
          HBox([t52.children[1],t52.children[2]]),
          HBox([t52.children[3]])])
output52 = t52.children[-1]


box51 = VBox([controls51, output51, hbox5_2, controls52, output52,  accordionind])
box51.layout = Layout(border="solid 5px lightblue", margin="10px 2px 2px 0px", padding="5px", width = "460px", height = "730px")

box5_1 = VBox([hbox5_1, box51])
###########################################################################################################################

############################# Box 4_2  = t-test for the difference###################################################################
##### From Parameters to effect Size
def t_test53(MeanS1, MeanS2, Sig1, Sig2, pairs, correlation, MeanP):
    if any(i.isalpha() for i in MeanS1) != True and any(i.isalpha() for i in MeanS2) !=True and any(i.isalpha() for i in Sig1) !=True and Sig1>"0" and any(i.isalpha() for i in Sig2) !=True and Sig2>"0" and pairs.isdigit()==True and correlation <= "1" and correlation >="-1" and "," not in Sig1 and "," not in MeanS1 and "," not in MeanS2 and "," not in Sig2 and (MeanS1 and Sig1 and Sig2 and MeanS2 and pairs and correlation) !="":
      MeanP = float(MeanP); MeanS1 = float(MeanS1); MeanS2 = float(MeanS2); Sig1 = float(Sig1); Sig2 = float(Sig2); pairs = float(pairs); cor = float(correlation);  
      diff = abs(MeanP - (MeanS1-MeanS2))
      SDiff = np.sqrt(Sig1**2+Sig2**2 - 2*cor*Sig1*Sig2)
      df = pairs - 1
      dz = abs(diff/SDiff)
      SE = SDiff/np.sqrt(pairs)
      gz = dz * (1 - (3/(4*df-1)))
      correction = (np.sqrt(2*(1-cor)))
      drm = dz* correction
      grm = drm*(1 - (3/(4*df-1)))
      dav = diff/np.sqrt(((Sig1**2+Sig2**2)/2))
      gav = dav * (1 - (3/(4*df-1)))
      t = abs(diff/SE)
      pval = min(((stats.t.sf((abs(t)), (df)))*2), 0.99999)

      print(f"t-score = {round(t,7)}\np-value(2-tailed) = {round(pval,7)}\n\n Cohen's dz = {round(dz,7)}  Hedges gz = {round(gz,7)}\n\nCohens' drm = {round(drm,7)}  Hedges grm = {round(grm,7)}\n\nCohens' dav = {round(dav,7)}  Hedges gav = {round(gav,7)}")
    elif MeanS1 == "":
      print(Fore.RED + "Please define mean1 above")
    elif MeanS2 == "":
      print(Fore.RED + "Please define mean2 above")
    elif Sig1 == "":
      print(Fore.RED + "Please define SD1 above")
    elif Sig2 == "":
      print(Fore.RED + "Please define SD2 above")
    elif pairs == "":
      print(Fore.RED + "Please define N pairs")
    elif correlation == "":
      print(Fore.RED + "Please define Correlation between measures")
    else:
      print(Fore.YELLOW + Back.RED + "Warnning!!! You have just entered an illegal character")

#Styling
style = {'description_width': 'initial'}    
T53 = interactive(t_test53, {'manual': True},MeanS1 = "", MeanS2 = "", Sig1 = "", Sig2 = "", pairs = "", correlation = "", MeanP="0")
T53.children[0].layout = Layout(width='194px', padding = "0px 21px 0px 0px")
T53.children[1].layout = Layout(width='185px') 
T53.children[2].layout = Layout(width='193px', padding = "0px 20px 0px 0px")
T53.children[3].layout = Layout(width='186px')
T53.children[4].layout = Layout(width='193.2px', padding = "0px 20px 0px 0px")
T53.children[5].layout = Layout(width='186px') 
T53.children[6].layout = Layout(width='250px')
T53.children[0].style = style 
T53.children[1].style = style 
T53.children[2].style = style 
T53.children[3].style = style
T53.children[4].style = style
T53.children[5].style = style
T53.children[6].style = style
T53.children[0].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;"> Sample1 Mean </span> <span style="color: white;">.</span> </p>' 
T53.children[1].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;"> Sample2 Mean </span> <span style="color: white;"></span> </p>'
T53.children[2].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;"> Sample1 SD </span> <span style="color: white;">_.__</span> </p>'
T53.children[3].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;"> Sample2 SD </span> <span style="color: white;">___</span> </p>' 
T53.children[4].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;"> N pairs </span> <span style="color: white;">_____</span> </p>' 
T53.children[5].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;"> Correlation </span> <span style="color: white;">....</span> </p>'
T53.children[6].description = " <b>*Difference In the Population </b>";
T53.children[7].style.button_color="lightblue"
T53.children[7].description="Estimated Cohen's d + Hedges` g";
T53.children[7].style.font_weight = "bold" 
T53.children[7].layout = Layout(width='250px')

##### From T to effect Size
controls53 = VBox([HBox([T53.children[0],T53.children[1]]),
                  HBox([T53.children[2],T53.children[3]]),
                  HBox([T53.children[4],T53.children[5]]),
                  HBox([T53.children[6]]),
                  HBox([T53.children[7]])])
output53 = T53.children[-1]


bes = widgets.Image(value=image8,format='png',width="150px",height="150px",)

box53 = VBox([controls53, output53])
box53.layout = Layout(border="solid 5px lightblue", padding="10px", margin="5px 10px 5px 10px", width = "490px", height = "595px")

###########################################################################################################################
box5_2 = VBox([hbox5_3, box53])

###########################################################################################################################




###########################################################################################################################
box5 = HBox([box5_1, box5_2])
box5.layout = Layout(border="solid 2px indianred", padding="10px", margin="5px 5px 0px 0px", width = "1000px", height = "655px")



###########################################################################################################################
##############################################   6.One way ANOVA - Between   #############################################
########                                                                                                            #######
###########################################################################################################################                                                                                                            
###########################################################################################################################

#headers
bbox1 = widgets.HTML(value= '<p style = "word-wrap: break-word; color: black; font-size: 120%; text-align: center;" > <b><u> From parameters Between-Subjects ANOVA </u></b> </p>')
bbox2 = widgets.HTML(value= '<p style = "word-wrap: break-word; color: black; font-size: 120%; text-align: center;" > <b><u> From Sum of squares or F </u></b> </p>')
bbox2_1 = widgets.HTML(value= '<p style = "word-wrap: break-word; color: black; font-size: 120%; text-align: center;" > <b><u> From F statitstics and DF`s </u></b> </p>')
bbox2_2 = widgets.HTML(value= '<p style = "word-wrap: break-word; color: black; font-size: 120%; text-align: left;" > <b><u> From F and Degrees of Freedoms </u></b> </p>')
bbox3 = widgets.HTML(value= '<p style = "word-wrap: break-word; color: black; font-size: 120%; text-align: center;" > <b><u> Generalized eta square + Generalized Omega Square </u></b> </p>')
bbox3_1 = widgets.HTML(value= '<p style = "word-wrap: break-word; color: black; font-size: 120%; text-align: left;" > <b><u> Between Subjects Designs </u></b> </p>')
bbox3_2 = widgets.HTML(value= '<p style = "word-wrap: break-word; color: black; font-size: 120%; text-align: left;" > <b><u> Within Subjects Designs </u></b> </p>')
bbox3_3 = widgets.HTML(value= '<p style = "word-wrap: break-word; border-top: 5px solid lightblue; color: black; font-size: 120%; text-align: left;" > <b><u> Mixed Subjects Designs </u></b> </p>')
bbox3_4 = widgets.HTML(value= '<p style = "border-left: 5px solid lightblue; color: white; writing-mode: vertical-rl; text-orientation: mixed;font-size: 25%; text-align: center;" > <b><u>Ani Ashir Lach Shir Al Dvarim Shelo Amarti Lach Im Manguna Pratit Shir Rak Lach VeLIAni Ashir Lach Shir Al Dvarim Shelo Amarti Lach Im Manguna Pratit Shir Rak Lach VeLI</u></b> </p>')

###############################################################################################################################
############################# Box 6.1 ANOVA from parameters ###################################################################
###############################################################################################################################

def anovab611(n1,m1,se1,sd1,n2,m2,se2, sd2, n3,m3,se3,sd3):
    if  se1 > "0" and se2 > "0" and se3 > "0" :
        m1 = float(m1); m2 = float(m2); m3 = float(m3); n1 = float(n1); n2 = float(n2); n3 = float(n3); se1 = float(se1); se2 = float(se2); se3 = float(se3); 
        m = (n1*m1+n2*m2+n3*m3)/(n1+n2+n3)
        std1 = se1*np.sqrt(n1-1);std2 = se2*np.sqrt(n2-1);std3 = se3*np.sqrt(n3-1)
        ssb = (n1*(m1-m)**2) + (n2*(m2-m)**2) + (n3*(m3-m)**2)
        ssw = n1*std1**2 + n2*std2**2 + n3*std3**2
        dfb = 2
        dfw = int((n1+n2+n3)-3)
        msb = ssb/dfb
        msw = ssw/dfw
        F = msb/msw
        eta= ssb/(ssb+ssw) 
        pval = stats.f.sf(F,dfb,dfw)
        print(f"p-value(2-tailed)= {round(pval,7)}\nEta\u00b2 (η\u00b2) = {round(eta,7)}, F({dfb},{dfw}) = {round(F,7)}")
    if  sd1 > "0" and sd2 > "0" and sd3 > "0" :
        m1 = float(m1); m2 = float(m2); m3 = float(m3); n1 = float(n1); n2 = float(n2); n3 = float(n3); sd1 = float(sd1); sd2 = float(sd2); sd3 = float(sd3); 
        m = (n1*m1+n2*m2+n3*m3)/(n1+n2+n3)
        ssb = (n1*(m1-m)**2) + (n2*(m2-m)**2) + (n3*(m3-m)**2)
        ssw = n1*sd1**2 + n2*sd2**2 + n3*sd3**2
        dfb = 2
        dfw = int((n1+n2+n3)-3)
        msb = ssb/dfb
        msw = ssw/dfw
        F = msb/msw
        eta= ssb/(ssb+ssw) 
        pval = stats.f.sf(F,dfb,dfw)
        print(f"p-value(2-tailed)= {round(pval,7)}\nEta\u00b2 (η\u00b2) = {round(eta,7)}, F({dfb},{dfw}) = {round(F,7)}")
    
accordionb = widgets.Accordion(children=[
    widgets.HTML(value= '<style>p{word-wrap: break-word}</style> <p>' "now i can write here whatever i want on hedges` and check if there is a text wrapping or not" +' </p>'),
    widgets.HTML(value= '<style>p{word-wrap: break-word}</style> <p>' "Cohen’s g (Cohen, 1988) is specifically for the case where the expected proportion in the population is 0.5 (50%). It is then simply the difference of the sample proportion with this 0.5." +' </p>'),
    widgets.HTML(value= '<style>p{word-wrap: break-word}</style> <p>' "Cohen’s g (Cohen, 1988) is specifically for the case where the expected proportion in the population is 0.5 (50%). It is then simply the difference of the sample proportion with this 0.5." +' </p>'),
    widgets.Image(value=image4,format='png',width=300,height=400,),
    widgets.Image(value=image4,format='png',width=300,height=400,),]) 
accordionb.set_title(0, 'Effect sizes interpretation'); 
accordionb.set_title(1, 'More info on Cohens h & Cohens g');
accordionb.set_title(2, 'More info on odds ratio and risk ratio');
accordionb.set_title(3, 'More info on Cohens formulae');
accordionb.set_title(4, 'More info on other effect sizes formulae');
accordionb.selected_index = None
        
        
#Styling
style = {'description_width': 'initial'}    
b611 = interactive(anovab611, {'manual': True},n1="", m1="", se1="", sd1="",n2="", m2="", se2="",sd2="",n3="", m3="", se3="",sd3="")
b611.children[0].layout = Layout(width='70px')
b611.children[1].layout = Layout(width='100px', margin = "5px 5px 5px 10px")
b611.children[2].layout = Layout(width='110px', margin = "5px 5px 5px 10px")
b611.children[3].layout = Layout(width='120px', margin = "5px 5px 5px 10px")
b611.children[4].layout = Layout(width='70px')
b611.children[5].layout = Layout(width='100px', margin = "5px 5px 5px 10px") 
b611.children[6].layout = Layout(width='110px', margin = "5px 5px 5px 10px")
b611.children[7].layout = Layout(width='120px', margin = "5px 5px 5px 10px")
b611.children[8].layout = Layout(width='70px') 
b611.children[9].layout = Layout(width='100px', margin = "5px 5px 5px 10px")
b611.children[10].layout = Layout(width='110px',margin = "5px 5px 5px 10px")
b611.children[11].layout = Layout(width='120px',margin = "5px 5px 5px 10px") 

b611.children[0].description = "<b>N1</b>"
b611.children[1].description = "<b>Mean1</b>"
b611.children[2].description = "<b>SE1</b>"
b611.children[3].description = '<p <span style ="color: black; font-weight: 300; font-size: 100%;"> OR </span> <span style="color: white;">__</span> <span style="color: black; font-weight:bold;">SD1</span> </p>'
b611.children[4].description = "<b>N2</b>"
b611.children[5].description = "<b>Mean2</b>"
b611.children[6].description = "<b>SE2</b>"
b611.children[7].description = '<p <span style ="color: black; font-weight: 300; font-size: 100%;"> OR </span> <span style="color: white;">__</span> <span style="color: black; font-weight:bold;">SD2</span> </p>'
b611.children[8].description = "<b>N3</b>"
b611.children[9].description = "<b>Mean3</b>"
b611.children[10].description = "<b>SE3</b>"
b611.children[11].description = '<p <span style ="color: black; font-weight: 300; font-size: 100%;"> OR </span> <span style="color: white;">__</span> <span style="color: black; font-weight:bold;">SD3</span> </p>'


b611.children[0].style = style;
b611.children[1].style = style;
b611.children[2].style = style;
b611.children[3].style = style;
b611.children[4].style = style;
b611.children[5].style = style;
b611.children[6].style = style;
b611.children[7].style = style;
b611.children[8].style = style;
b611.children[9].style = style;
b611.children[10].style = style;
b611.children[11].style = style;

b611.children[12].style.button_color="lightblue";
b611.children[12].description="Calculate Effect Size";
b611.children[12].style.font_weight = "bold";
b611.children[12].layout = Layout(width='200px')

controls611 = VBox([
          HBox([b611.children[0],b611.children[1], b611.children[2], b611.children[3] ]),
          HBox([b611.children[4],b611.children[5], b611.children[6], b611.children[7] ]),
          HBox([b611.children[8],b611.children[9], b611.children[10], b611.children[11] ]),
          HBox([b611.children[12]]),])
output611 = b611.children[-1]

b611box = VBox([controls611,output611])

def anovab612(m1,m2,m3,m4,s1,s2,s3,s4,n1,n2,n3,n4):
    if s1>="0" and s2>="0" and s3>="0" and s4> "0":
        m1 = float(m1); m2 = float(m2); m3 = float(m3); m4 = float(m4); n1 = float(n1); n2 = float(n2); n3 = float(n3); n4 = float(n4); s1 = float(s1); s2 = float(s2); s3 = float(s3); s4 = float(s4); 
        m = (n1*m1+n2*m2+n3*m3+n4*m4)/(n1+n2+n3+n4)
        sd1 = s1*np.sqrt(n1-1);sd2 = s2*np.sqrt(n2-1);sd3 = s3*np.sqrt(n3-1);sd4 = s4*np.sqrt(n4-1)
        ssb = (n1*(m1-m)**2) + (n2*(m2-m)**2) + (n3*(m3-m)**2) + (n4*(m4-m)**2)
        ssw = n1*sd1**2 + n2*sd2**2 + n3*sd3**2 + n4*sd4**2
        dfb = 3
        dfw = int((n1+n2+n3)-4)
        msb = ssb/dfb
        msw = ssw/dfw
        F = msb/msw
        eta= ssb/(ssb+ssw) 
        pval = stats.f.sf(F,dfb,dfw)
        print(f"p-value(2-tailed)= {round(pval,7)}\nEta\u00b2 (η\u00b2) = {round(eta,7)}, F({dfb},{dfw}) = {round(F,7)}")
    elif m1 or m2 or m3 == "":
        print(Fore.RED + "Please define all means above")
    elif n1 or n2 or n3 == "":
        print(Fore.RED + "Please define the size of all samples above")
    elif s1 or s2 or s3 == "":
        print(Fore.RED + "Please define all SD's above")
    else:
        print(Fore.YELLOW + Back.RED + "Warnning!!! You have just entered an illegal character")

b612 = interactive(anovab612, {'manual': True},n1="", m1="", s1="",n2="", m2="", s2="",n3="", m3="", s3="",n4="", m4="", s4="")
b612.children[0].layout = Layout(width='100px')
b612.children[1].layout = Layout(width='130px', margin = "5px 5px 5px 10px")
b612.children[2].layout = Layout(width='130px')
b612.children[3].layout = Layout(width='100px')
b612.children[4].layout = Layout(width='130px', margin = "5px 5px 5px 10px")
b612.children[5].layout = Layout(width='130px') 
b612.children[6].layout = Layout(width='100px')
b612.children[7].layout = Layout(width='130px',margin = "5px 5px 5px 10px")
b612.children[8].layout = Layout(width='130px') 
b612.children[9].layout = Layout(width='100px')
b612.children[10].layout = Layout(width='130px',margin = "5px 5px 5px 10px")
b612.children[11].layout = Layout(width='130px')

b612.children[0].description = "<b>N1</b>"
b612.children[1].description = "<b>Mean1</b>"
b612.children[2].description = "<b>SE1</b>"
b612.children[3].description = "<b>N2</b>"
b612.children[4].description ="<b>Mean2</b>"
b612.children[5].description = "<b>SE2</b>"
b612.children[6].description = "<b>N3</b>"
b612.children[7].description = "<b>Mean3</b>"
b612.children[8].description = "<b>SE3</b>"
b612.children[9].description = "<b>N4</b>"
b612.children[10].description = "<b>Mean4</b>"
b612.children[11].description = "<b>SE4</b>"

b612.children[0].style = style;
b612.children[1].style = style;
b612.children[2].style = style;
b612.children[3].style = style;
b612.children[4].style = style;
b612.children[5].style = style;
b612.children[6].style = style;
b612.children[7].style = style;
b612.children[8].style = style;
b612.children[9].style = style;
b612.children[10].style = style;
b612.children[11].style = style;
b612.children[12].style.button_color="lightblue";
b612.children[12].description="Calculate Effect Size";
b612.children[12].style.font_weight = "bold";
b612.children[12].layout = Layout(width='200px')

controls612 = VBox([
          HBox([b612.children[0],b612.children[1], b612.children[2]]),
          HBox([b612.children[3],b612.children[4], b612.children[5]]),
          HBox([b612.children[6],b612.children[7], b612.children[8]]),
          HBox([b612.children[9],b612.children[10], b612.children[11]]),
          HBox([b612.children[12]]),])
output612 = b612.children[-1]

b612box = VBox([controls612,output612])

def anovab613(m1,m2,m3,m4,m5,s1,s2,s3,s4,s5,n1,n2,n3,n4,n5):
    if s1>="0" and s2>="0" and s3>="0" and s4> "0":
        m1 = float(m1); m2 = float(m2); m3 = float(m3); m4 = float(m4); m5 = float(m5); n1 = float(n1); n2 = float(n2); n3 = float(n3); n4 = float(n4); n5 = float(n5); s1 = float(s1); s2 = float(s2); s3 = float(s3); s4 = float(s4); s5 = float(s5);
        m = (n1*m1+n2*m2+n3*m3+n4*m4+n5*m5)/(n1+n2+n3+n4+n5)
        sd1 = s1*np.sqrt(n1-1);sd2 = s2*np.sqrt(n2-1);sd3 = s3*np.sqrt(n3-1);sd4 = s4*np.sqrt(n4-1);sd5 = s5*np.sqrt(n5-1)
        ssb = (n1*(m1-m)**2) + (n2*(m2-m)**2) + (n3*(m3-m)**2) + (n4*(m4-m)**2) + (n5*(m5-m)**2)
        ssw = n1*sd1**2 + n2*sd2**2 + n3*sd3**2 + n4*sd4**2 + n5*sd5**2
        dfb = 4
        dfw = int((n1+n2+n3)-5)
        msb = ssb/dfb
        msw = ssw/dfw
        F = msb/msw
        eta= ssb/(ssb+ssw) 
        pval = stats.f.sf(F,dfb,dfw)
        print(f"p-value(2-tailed)= {round(pval,7)}\nEta\u00b2 (η\u00b2) = {round(eta,7)}, F({dfb},{dfw}) = {round(F,7)}")
    elif m1 or m2 or m3 == "":
        print(Fore.RED + "Please define all means above")
    elif n1 or n2 or n3 == "":
        print(Fore.RED + "Please define the size of all samples above")
    elif s1 or s2 or s3 == "":
        print(Fore.RED + "Please define all SD's above")
    else:
        print(Fore.YELLOW + Back.RED + "Warnning!!! You have just entered an illegal character")

#Styling
b613 = interactive(anovab613, {'manual': True},n1="", m1="", s1="",n2="", m2="", s2="",n3="", m3="", s3="",n4="", m4="", s4="",n5="", m5="", s5="")
b613.children[0].layout = Layout(width='70px')
b613.children[1].layout = Layout(width='130px', margin = "5px 5px 5px 10px")
b613.children[2].layout = Layout(width='130px')
b613.children[3].layout = Layout(width='100px')
b613.children[4].layout = Layout(width='70px', margin = "5px 5px 5px 10px")
b613.children[5].layout = Layout(width='130px') 
b613.children[6].layout = Layout(width='100px')
b613.children[7].layout = Layout(width='130px',margin = "5px 5px 5px 10px")
b613.children[8].layout = Layout(width='70px') 
b613.children[9].layout = Layout(width='100px')
b613.children[10].layout = Layout(width='130px',margin = "5px 5px 5px 10px")
b613.children[11].layout = Layout(width='130px')
b613.children[12].layout = Layout(width='70px')
b613.children[13].layout = Layout(width='130px',margin = "5px 5px 5px 10px")
b613.children[14].layout = Layout(width='130px')

b613.children[0].description = "<b>N1</b>"
b613.children[1].description = "<b>Mean1</b>"
b613.children[2].description = "<b>SE1</b>"
b613.children[3].description = "<b>N2</b>"
b613.children[4].description ="<b>Mean2</b>"
b613.children[5].description = "<b>SE2</b>"
b613.children[6].description = "<b>N3</b>"
b613.children[7].description = "<b>Mean3</b>"
b613.children[8].description = "<b>SE3</b>"
b613.children[9].description = "<b>N4</b>"
b613.children[10].description = "<b>Mean4</b>"
b613.children[11].description = "<b>SE4</b>"
b613.children[12].description = "<b>N5</b>"
b613.children[13].description = "<b>Mean5</b>"
b613.children[14].description = "<b>SE5</b>"
b613.children[0].style = style;
b613.children[1].style = style;
b613.children[2].style = style;
b613.children[3].style = style;
b613.children[4].style = style;
b613.children[5].style = style;
b613.children[6].style = style;
b613.children[7].style = style;
b613.children[8].style = style;
b613.children[9].style = style;
b613.children[10].style = style;
b613.children[11].style = style;
b613.children[12].style = style;
b613.children[13].style = style;
b613.children[14].style = style;
b613.children[15].style.button_color="lightblue";
b613.children[15].description="Calculate Effect Size";
b613.children[15].style.font_weight = "bold";
b613.children[15].layout = Layout(width='200px')

controls613 = VBox([
          HBox([b613.children[0],b613.children[1], b613.children[2]]),
          HBox([b613.children[3],b613.children[4], b613.children[5]]),
          HBox([b613.children[6],b613.children[7], b613.children[8]]),
          HBox([b613.children[9],b613.children[10], b613.children[11]]),
          HBox([b613.children[12],b613.children[13], b613.children[14]]),
          HBox([b613.children[15]]),])
output613 = b613.children[-1]

b613box = VBox([controls613,output613])

b61_box = widgets.Dropdown(options=(("3 Groups",b611box),("4 Groups",b612box), ("5 Groups",b613box)))
b61_box.layout = Layout(width = "385px")
b61_box.description = '<p <span style ="color: red; font-weight: bold; font-size: 100%;"> Choose the Number of Groups </span> </p>'
b61_box.style = style

def view(x=""):
    display(x)
ANOVA1 = interactive(view,x=b61_box)

b6_box1 = VBox([bbox1, ANOVA1, accordionb])
b6_box1.children[1].layout = Layout(border="solid 5px lightblue", margin="5px 5px 5px 5px", padding="0px 0px 0px 0px", width = "480px", height = "450px")

################################################################################################################################################
############################# Box 6_2 = FROM SS and statistic to effect size ###################################################################
################################################################################################################################################

def anovab621(sseffect, sserror):
    eta = sseffect/sserror+sseffect
    print(f"Eta\u00b2 (η\u00b2) = {round(eta,7)}")

#Styling
style = {'description_width': 'initial'}    
b621 = interactive(anovab621, {'manual': True}, sseffect = widgets.BoundedFloatText(), sserror = widgets.BoundedFloatText())
b621.children[0].layout = Layout(width='180px');
b621.children[1].layout = Layout(width='180px');
b621.children[1].description = "<b>SSerror </b>";
b621.children[0].description = "<b>SSeffect </b>";
b621.children[2].style.button_color="lightblue";
b621.children[2].description="Calculate Eta\u00b2 (η\u00b2)";
b621.children[2].style.font_weight = "bold";
b621.children[2].layout = Layout(width='180px', margin = "10px")

controls621 = VBox([
          HBox([b621.children[0]]),
          HBox([b621.children[1]]),
          HBox([b621.children[2]]),])
output621 = b621.children[-1]


b621box = VBox([bbox2_1, controls621, output621])

b62_box = VBox([b621box])
b62_box.layout = Layout(border="solid 5px lightblue", margin="5px 5px 5px 5px", padding="0px 0px 0px 0px", width = "220px", height = "790px")


b6_box2 = VBox([bbox2, b62_box])  


################################################################################################################
################################################# Box 6.3 - Generalized Eta Square #############################
################################################################################################################
     
##### Box6.3.1 Between Subject  #######  
def anovab6311(v1, ssa, sse, dfa, dferror):
    if v1 == "Manipulable": 
       v1 = float(v1); ssa = float(ssa); sse = float(sse); dfa = float(dfa); dfe = float(dfe);  
       eta = ssa 
       print(f"p-value(2-tailed)= {round(eta,7)}")
    elif v1 == "Measured" and v2 == "Measured":
       v1 = float(v1); v2 = float(v2); ssa = float(ssa); ssb = float(ssb); ssab = float(ssab); sse = float(sse);
       eta = ssa
       print(f"p-value(2-tailed)= {round(eta,7)}")

style = {'description_width': 'initial'}    
b6311 = interactive(anovab6311, {'manual': True},v1=widgets.Dropdown(options=(("Manipulable"),("Measured"))), ssa="", sse="", dfa ="", dferror = "")
b6311.children[0].layout = Layout(width='150px',margin = "0px 10px 0px 10px")
b6311.children[1].layout = Layout(width='120px' ,margin = "0px 10px 0px 10px")
b6311.children[2].layout = Layout(width='120px',margin = "0px 10px 0px 10px")
b6311.children[3].layout = Layout(width='100px',margin = "0px 0px 0px 10px")
b6311.children[4].layout = Layout(width='100px',margin = "0px 0px 0px 10px")

b6311.children[0].description = "<b>Type A</b>"
b6311.children[1].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;">SSA</span><span style="color: white;">____</span> </p>'
b6311.children[2].description = "<b>SSError</b>"
b6311.children[3].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;">DFa</span><span style="color: white;">_..__</span> </p>'
b6311.children[4].description = "<b>DFerror</b>"

b6311.children[0].style = style;
b6311.children[1].style = style;
b6311.children[2].style = style;
b6311.children[3].style = style;
b6311.children[4].style = style;
                                  
b6311.children[5].style.button_color="lightblue";
b6311.children[5].description="Calculate Effect Size";
b6311.children[5].style.font_weight = "bold";
b6311.children[5].layout = Layout(width='150px', margin = "0px 10px 0px 0px")

controls6311 = HBox([
          VBox([b6311.children[0], b6311.children[5]]),
          VBox([b6311.children[1], b6311.children[2]]),
          VBox([b6311.children[3], b6311.children[4]])])

output6311 = b6311.children[-1]

box6311 = VBox([controls6311,output6311])

                                                                     
def anovab6312(v1, v2, ssa, ssb, ssab, sse, dfa,dfb, dfab,dfe):
    if v1 == "Manipulable" and v2 == "Manipulable": 
       v1 = float(v1); v2 = float(v2); ssa = float(ssa); ssb = float(ssb); ssab = float(ssab); sse = float(sse); dfa = float(dfa); dfb = float(dfb); dfab = float(dfab); dfe = float(dfe) 
       eta = ssa+ssb 
       print(f"p-value(2-tailed)= {round(eta,7)}")
    elif v1 == "Manipulable" and v2 == "Measured":
       v1 = float(v1); v2 = float(v2); ssa = float(ssa); ssb = float(ssb); ssab = float(ssab); sse = float(sse);
       eta = ssa+ssb 
       print(f"p-value(2-tailed)= {round(eta,7)}")
    elif v1 == "Measured" and v2 == "Manipulable":
       v1 = float(v1); v2 = float(v2); ssa = float(ssa); ssb = float(ssb); ssab = float(ssab); sse = float(sse);   
       eta = ssa+ssb 
       print(f"p-value(2-tailed)= {round(eta,7)}")
    elif v1 == "Measured" and v2 == "Measured":
       v1 = float(v1); v2 = float(v2); ssa = float(ssa); ssb = float(ssb); ssab = float(ssab); sse = float(sse); 
       eta = ssa+ssb 
       print(f"p-value(2-tailed)= {round(eta,7)}")
                                                                        
#Styling
style = {'description_width': 'initial'}    
b6312 = interactive(anovab6312, {'manual': True},v1=widgets.Dropdown(options=(("Manipulable"),("Measured"))), v2=widgets.Dropdown(options=(("Manipulable"),("Measured"))), ssa="", ssb="", ssab="",sse="", dfa="",dfb="",dfab="",dfe="")
b6312.children[0].layout = Layout(width='150px', margin = "0px 10px 0px 10px")
b6312.children[1].layout = Layout(width='150px', margin = "0px 10px 0px 10px")
b6312.children[2].layout = Layout(width='120px', margin = "0px 10px 0px 10px")
b6312.children[3].layout = Layout(width='120px', margin = "0px 10px 0px 10px")
b6312.children[4].layout = Layout(width='120px', margin = "0px 10px 0px 10px")
b6312.children[5].layout = Layout(width='120px', margin = "0px 10px 0px 10px") 
b6312.children[6].layout = Layout(width='100px', margin = "0px 10px 0px 0px")
b6312.children[7].layout = Layout(width='100px', margin = "0px 10px 0px 0px")
b6312.children[8].layout = Layout(width='100px', margin = "0px 10px 0px 0px")
b6312.children[9].layout = Layout(width='100px', margin = "0px 10px 0px 0px")



b6312.children[0].description = "<b>Type A</b>"
b6312.children[1].description = "<b>Type B</b>"
b6312.children[2].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;"> </span>SSA<span style="color: white;">____</span> </p>'
b6312.children[3].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;"> </span>SSB<span style="color: white;">____</span> </p>'
b6312.children[4].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;"> </span>SSAB<span style="color: white;">.__</span> </p>'
b6312.children[5].description = "<b>SSError</b>"
b6312.children[6].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;"> </span>DFa<span style="color: white;">____</span> </p>'
b6312.children[7].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;"> </span>DFb<span style="color: white;">____</span> </p>'
b6312.children[8].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;"> </span>DFAB<span style="color: white;">.__</span> </p>'
b6312.children[9].description = "<b>DFerror</b>"

b6312.children[0].style = style;
b6312.children[1].style = style;
b6312.children[2].style = style;
b6312.children[3].style = style;
b6312.children[4].style = style;
b6312.children[5].style = style;
b6312.children[6].style = style;
b6312.children[7].style = style;
b6312.children[8].style = style;
b6312.children[9].style = style;
                                  
b6312.children[10].style.button_color="lightblue";
b6312.children[10].description="Calculate Effect Size";
b6312.children[10].style.font_weight = "bold";
b6312.children[10].layout = Layout(width='150px')

controls6312 = HBox([
          VBox([b6312.children[0], b6312.children[1],b6312.children[10]]),
          VBox([b6312.children[2], b6312.children[3], b6312.children[4], b6312.children[5]]),
          VBox([b6312.children[6], b6312.children[7],b6312.children[8], b6312.children[9]])])
output6312 = b6312.children[-1]

box6312 = VBox([controls6312,output6312])


def anovab6313(v1, v2, v3, ssa, ssb, ssc, ssab, ssac, ssbc, ssabc, sse, dfa,dfb,dfc, dfab, dfac, dfbc, dfabc, dfe):
    if v1 == "Manipulable":
       v1 = float(v1); v2 = float(v2); ssa = float(ssa); ssb = float(ssb); ssab = float(ssab); sse = float(sse); dfa = float(dfa); dfb = float(dfb); dfab = float(dfab); dfe = float(dfe)  
       v1 = float(v1); ssa = float(ssa); sse = float(sse); 
       eta = ssa 
       print(f"p-value(2-tailed)= {round(eta,7)}")
    elif v1 == "Measured" and v2 == "Measured":
       v1 = float(v1); v2 = float(v2); ssa = float(ssa); ssb = float(ssb); ssab = float(ssab); sse = float(sse);
       eta = ssa
       print(f"p-value(2-tailed)= {round(eta,7)}")
    
#Styling
style = {'description_width': 'initial'}    
b6313 = interactive(anovab6313, {'manual': True},v1=widgets.Dropdown(options=(("Manipulable"),("Measured"))), v2=widgets.Dropdown(options=(("Manipulable"),("Measured"))),v3=widgets.Dropdown(options=(("Manipulable"),("Measured"))), ssa="", ssb="", ssc="",ssab="", ssac="",ssbc="",ssabc="",sse="",dfa="",dfb="",dfc="",dfab="",dfac="",dfbc="",dfabc="",dfe="")
b6313.children[0].layout = Layout(width='150px', margin = "0x 10px 0px 10px")
b6313.children[1].layout = Layout(width='150px', margin = "0x 10px 0px 10px")
b6313.children[2].layout = Layout(width='150px', margin = "0x 10px 0px 10px")
b6313.children[3].layout = Layout(width='120px', margin = "0x 10px 0px 10px")
b6313.children[4].layout = Layout(width='120px',margin = "0x 10px 0px 10px")
b6313.children[5].layout = Layout(width='120px', margin = "0x 10px 0px 10px") 
b6313.children[6].layout = Layout(width='120px',margin = "0x 10px 0px 10px")
b6313.children[7].layout = Layout(width='120px',margin = "0x 10px 0px 10px")
b6313.children[8].layout = Layout(width='120px',margin = "0x 10px 0px 10px")
b6313.children[9].layout = Layout(width='120px',margin = "0x 10px 0px 10px")
b6313.children[10].layout = Layout(width='120px',margin = "0x 10px 0px 10px")
b6313.children[11].layout = Layout(width='100px',) 
b6313.children[12].layout = Layout(width='100px') 
b6313.children[13].layout = Layout(width='100px')
b6313.children[14].layout = Layout(width='100px')
b6313.children[15].layout = Layout(width='100px')
b6313.children[16].layout = Layout(width='100px')
b6313.children[17].layout = Layout(width='100px')
b6313.children[18].layout = Layout(width='100px')

b6313.children[0].description = "<b>Type A</b>"
b6313.children[1].description = "<b>Type B</b>"
b6313.children[2].description = "<b>Type C</b>"
b6313.children[3].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;">SSA</span><span style="color: white;">____</span> </p>'
b6313.children[4].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;">SSB</span><span style="color: white;">____</span> </p>'
b6313.children[5].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;">SSC</span><span style="color: white;">____</span> </p>'
b6313.children[6].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;">SSAB</span><span style="color: white;">.__</span> </p>'
b6313.children[7].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;">SSAC</span><span style="color: white;">.__</span> </p>'
b6313.children[8].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;">SSBC</span><span style="color: white;">.__</span> </p>'
b6313.children[9].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;">SSABC</span><span style="color: white;">.</span> </p>'
b6313.children[10].description = "<b>SSError</b>"
b6313.children[11].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;">DFa</span><span style="color: white;">____</span> </p>'
b6313.children[12].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;">DFb</span><span style="color: white;">____</span> </p>'
b6313.children[13].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;">DFc</span><span style="color: white;">____</span> </p>'
b6313.children[14].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;">DFab</span><span style="color: white;">..__</span> </p>'
b6313.children[15].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;">DFac</span><span style="color: white;">..__</span> </p>'
b6313.children[16].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;">DFbc</span><span style="color: white;">..__</span> </p>'
b6313.children[17].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;">DFabc</span><span style="color: white;">__</span> </p>'                                  
b6313.children[18].description = "<b>DFerror</b>"                                  
                                  
b6313.children[0].style = style;
b6313.children[1].style = style;
b6313.children[2].style = style;
b6313.children[3].style = style;
b6313.children[4].style = style;
b6313.children[5].style = style;
b6313.children[6].style = style;
b6313.children[7].style = style;
b6313.children[8].style = style;
b6313.children[9].style = style;
b6313.children[10].style = style;
b6313.children[11].style = style;
b6313.children[12].style = style;
b6313.children[13].style = style;
b6313.children[14].style = style;
b6313.children[15].style = style;
b6313.children[16].style = style;
b6313.children[17].style = style;
b6313.children[18].style = style;
                                  
b6313.children[19].style.button_color="lightblue";
b6313.children[19].description="Calculate Effect Size";
b6313.children[19].style.font_weight = "bold";
b6313.children[19].layout = Layout(width='200px')

controls6313 = HBox([
          VBox([b6313.children[0], b6313.children[1],b6313.children[2],b6313.children[20]]),
          VBox([b6313.children[3], b6313.children[4], b6313.children[5], b6313.children[6],b6313.children[7], b6313.children[8], b6313.children[9], b6313.children[10]]),
          VBox([b6313.children[11], b6313.children[12], b6313.children[13], b6313.children[14],b6313.children[15], b6313.children[16], b6313.children[17], b6313.children[18]]),])
output6313 = b6313.children[-1]

box6313 = VBox([controls6313,output6313])
                                                                     
                                                                               
b631_box = widgets.Dropdown(options=(("1 Variable",box6311),("2 Variables",box6312), ("3 Variables",box6313)))
b631_box.layout = Layout(width = "350px")
b631_box.description = '<p <span style ="color: red; font-weight: bold; font-size: 100%;"> How many Variables do you have? </span> </p>'
b631_box.style = style

def view(x=""):
    display(x)
ANOVA631 = interactive(view,x=b631_box)
ANOVA631.layout = Layout(margin="5px", padding="0px", width = "auto", height = "auto")
                                                                     
 
##### Box6.3.2 Within Subject                                                                                                                           
def anovab6321(v1, ssa, sss, dfa, dferror):
    if v1 == "Manipulable": 
       v1 = float(v1); ssa = float(ssa); sss = float(sss); 
       eta = ssa 
       print(f"p-value(2-tailed)= {round(eta,7)}")
    elif v1 == "Measured" and v2 == "Measured":
       v1 = float(v1); v2 = float(v2); ssa = float(ssa); ssb = float(ssb); ssab = float(ssab); sss = float(sss);
       eta = ssa
       print(f"p-value(2-tailed)= {round(eta,7)}")

style = {'description_width': 'initial'}    
b6321 = interactive(anovab6321, {'manual': True},v1=widgets.Dropdown(options=(("Manipulable"),("Measured"))), ssa="", sss="", dfa ="", dferror = "")
b6321.children[0].layout = Layout(width='150px',margin = "0x 10px 0px 10px")
b6321.children[1].layout = Layout(width='100px' ,margin = "0px 10px 0px 10px")
b6321.children[2].layout = Layout(width='100px',margin = "0px 10px 0px 10px")
b6321.children[3].layout = Layout(width='70px',margin = "0px 10px 0px 10px")
b6321.children[4].layout = Layout(width='70px',margin = "0px 10px 0px 10px")

b6321.children[0].description = "<b>Type A</b>"
b6321.children[1].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;">SSA</span><span style="color: white;">______</span> </p>'
b6321.children[2].description = "<b>SSsubjects</b>"
b6321.children[3].description = '<p <span style ="color: black; font-weight: bold; font-size: 100%;">DFa</span><span style="color: white;">____</span> </p>'
b6321.children[4].description = "<b>DFerror</b>"

b6321.children[0].style = style;
b6321.children[1].style = style;
b6321.children[2].style = style;
b6321.children[3].style = style;
b6321.children[4].style = style;
                                  
b6321.children[5].style.button_color="lightblue";
b6321.children[5].description="Calculate Effect Size";
b6321.children[5].style.font_weight = "bold";
b6321.children[5].layout = Layout(width='150px')

controls6321 = HBox([
          VBox([b6321.children[0], b6321.children[5]]),
          VBox([b6321.children[1], b6321.children[2]]),
          VBox([b6321.children[3], b6321.children[4]])])

output6321 = b6321.children[-1]

box6321 = VBox([controls6321,output6321])

                                                                     
def anovab6322(v1, v2, ssa, ssb, ssab, sse):
    if v1 == "Manipulable" and v2 == "Manipulable": 
       v1 = float(v1); v2 = float(v2); ssa = float(ssa); ssb = float(ssb); ssab = float(ssab); sse = float(sse); 
       eta = ssa+ssb 
       print(f"p-value(2-tailed)= {round(eta,7)}")
    elif v1 == "Manipulable" and v2 == "Measured":
       v1 = float(v1); v2 = float(v2); ssa = float(ssa); ssb = float(ssb); ssab = float(ssab); sse = float(sse);
       eta = ssa+ssb 
       print(f"p-value(2-tailed)= {round(eta,7)}")
    elif v1 == "Measured" and v2 == "Manipulable":
       v1 = float(v1); v2 = float(v2); ssa = float(ssa); ssb = float(ssb); ssab = float(ssab); sse = float(sse);   
       eta = ssa+ssb 
       print(f"p-value(2-tailed)= {round(eta,7)}")
    elif v1 == "Measured" and v2 == "Measured":
       v1 = float(v1); v2 = float(v2); ssa = float(ssa); ssb = float(ssb); ssab = float(ssab); sse = float(sse); 
       eta = ssa+ssb 
       print(f"p-value(2-tailed)= {round(eta,7)}")
                                                                        
#Styling
style = {'description_width': 'initial'}    
b6322 = interactive(anovab6322, {'manual': True},v1=widgets.Dropdown(options=(("Manipulable"),("Measured"))), v2=widgets.Dropdown(options=(("Manipulable"),("Measured"))), ssa="", ssb="", ssab="",sse="")
b6322.children[0].layout = Layout(width='130px')
b6322.children[1].layout = Layout(width='130px')# ,margin = "5px 5px 5px 5px")
b6322.children[2].layout = Layout(width='130px')
b6322.children[3].layout = Layout(width='130px')
b6322.children[4].layout = Layout(width='130px')
b6322.children[5].layout = Layout(width='130px') 

b6322.children[0].description = "<b>Type A</b>"
b6322.children[1].description = "<b>Type B</b>"
b6322.children[2].description = "<b>SSA</b>"
b6322.children[3].description = "<b>SSB</b>"
b6322.children[4].description = "<b>SSAB</b>"
b6322.children[5].description = "<b>SSError</b>"

b6322.children[0].style = style;
b6322.children[1].style = style;
b6322.children[2].style = style;
b6322.children[3].style = style;
b6322.children[4].style = style;
b6322.children[5].style = style;

b6322.children[6].style.button_color="lightblue";
b6322.children[6].description="Calculate Effect Size";
b6322.children[6].style.font_weight = "bold";
b6322.children[6].layout = Layout(width='200px')

controls6322 = VBox([
          HBox([b6322.children[0],b6322.children[1]]),
          HBox([b6322.children[2],b6322.children[3]]),
          HBox([b6322.children[4],b6322.children[5]]),
          HBox([b6322.children[6]]),])
output6322 = b6322.children[-1]

box6322 = VBox([controls6322,output6322])


def anovab6323(v1, v2, ssa, ssb, ssab, sse):
    if v1 == "Manipulable": 
       v1 = float(v1); ssa = float(ssa); sse = float(sse); 
       eta = ssa 
       print(f"p-value(2-tailed)= {round(eta,7)}")
    elif v1 == "Measured" and v2 == "Measured":
       v1 = float(v1); v2 = float(v2); ssa = float(ssa); ssb = float(ssb); ssab = float(ssab); sse = float(sse);
       eta = ssa
       print(f"p-value(2-tailed)= {round(eta,7)}")
    
#Styling
style = {'description_width': 'initial'}    
b6323 = interactive(anovab6323, {'manual': True},v1=widgets.Dropdown(options=(("Manipulable"),("Measured"))), v2=widgets.Dropdown(options=(("Manipulable"),("Measured"))), ssa="", ssb="", ssab="",sse="")
b6323.children[0].layout = Layout(width='130px')
b6323.children[1].layout = Layout(width='130px')# ,margin = "5px 5px 5px 5px")
b6323.children[2].layout = Layout(width='130px')
b6323.children[3].layout = Layout(width='130px')
b6323.children[4].layout = Layout(width='130px')
b6323.children[5].layout = Layout(width='130px') 

b6323.children[0].description = "<b>Type A</b>"
b6323.children[1].description = "<b>Type B</b>"
b6323.children[2].description = "<b>SSA</b>"
b6323.children[3].description = "<b>SSB</b>"
b6323.children[4].description = "<b>SSAB</b>"
b6323.children[5].description = "<b>SSError</b>"

b6323.children[0].style = style;
b6323.children[1].style = style;
b6323.children[2].style = style;
b6323.children[3].style = style;
b6323.children[4].style = style;
b6323.children[5].style = style;

b6323.children[6].style.button_color="lightblue";
b6323.children[6].description="Calculate Effect Size";
b6323.children[6].style.font_weight = "bold";
b6323.children[6].layout = Layout(width='200px')

controls6323 = VBox([
          HBox([b6323.children[0],b6323.children[1]]),
          HBox([b6323.children[2],b6323.children[3]]),
          HBox([b6323.children[4],b6323.children[5]]),
          HBox([b6323.children[6]]),])
output6323 = b6323.children[-1]

box6323 = VBox([controls6323,output6323])
                                                                                                                                            
b632_box = widgets.Dropdown(options=(("1 Variable",box6321),("2 Variables",box6312), ("3 Variables",box6323)))
b632_box.layout = Layout(width = "350px")
b632_box.description = '<p <span style ="color: green; font-weight: bold; font-size: 100%;"> How Many Variables Do You Have? </span> </p>'
b632_box.style = style

def view(x=""):
    display(x)
ANOVA632 = interactive(view,x=b632_box)
ANOVA632.layout = Layout(margin="5px", padding="0px", width = "auto", height = "auto")

####Mixed Designs
def anovab6331(v1, v2, ssa, sse):
    if v1 == "Manipulable": 
       v1 = float(v1); v2 = float(v2); ssa = float(ssa); sse = float(sse); 
       eta = ssa 
       print(f"p-value(2-tailed)= {round(eta,7)}")
    elif v1 == "Measured" and v2 == "Measured":
       v1 = float(v1); v2 = float(v2); ssa = float(ssa); ssb = float(ssb); ssab = float(ssab); sse = float(sse);
       eta = ssa
       print(f"p-value(2-tailed)= {round(eta,7)}")

style = {'description_width': 'initial'}    
b6331 = interactive(anovab6331, {'manual': True},v1=widgets.Dropdown(options=(("Manipulable"),("Measured"))), v2=widgets.Dropdown(options=(("Manipulable"),("Measured"))), ssa="", ssb="", ssab="",sse="")
b6331.children[0].layout = Layout(width='150px')
b6331.children[1].layout = Layout(width='150px')# ,margin = "5px 5px 5px 5px")
b6331.children[2].layout = Layout(width='150px')

b6331.children[0].description = "<b>Type A</b>"
b6331.children[1].description = "<b>SSA</b>"
b6331.children[2].description = "<b>SSError</b>"

b6331.children[0].style = style;
b6331.children[1].style = style;
b6331.children[2].style = style;

b6331.children[3].style.button_color="lightblue";
b6331.children[3].description="Calculate Effect Size";
b6331.children[3].style.font_weight = "bold";
b6331.children[3].layout = Layout(width='150px')

controls6331 = VBox([
          HBox([b6331.children[0],b6331.children[1],b6331.children[2]]),
          HBox([b6331.children[3]]),])
output6331 = b6331.children[-1]

box6331 = VBox([controls6331,output6331])

                                                                     
def anovab6332(v1, v2, ssa, ssb, ssab, sse):
    if v1 == "Manipulable" and v2 == "Manipulable": 
       v1 = float(v1); v2 = float(v2); ssa = float(ssa); ssb = float(ssb); ssab = float(ssab); sse = float(sse); 
       eta = ssa+ssb 
       print(f"p-value(2-tailed)= {round(eta,7)}")
    elif v1 == "Manipulable" and v2 == "Measured":
       v1 = float(v1); v2 = float(v2); ssa = float(ssa); ssb = float(ssb); ssab = float(ssab); sse = float(sse);
       eta = ssa+ssb 
       print(f"p-value(2-tailed)= {round(eta,7)}")
    elif v1 == "Measured" and v2 == "Manipulable":
       v1 = float(v1); v2 = float(v2); ssa = float(ssa); ssb = float(ssb); ssab = float(ssab); sse = float(sse);   
       eta = ssa+ssb 
       print(f"p-value(2-tailed)= {round(eta,7)}")
    elif v1 == "Measured" and v2 == "Measured":
       v1 = float(v1); v2 = float(v2); ssa = float(ssa); ssb = float(ssb); ssab = float(ssab); sse = float(sse); 
       eta = ssa+ssb 
       print(f"p-value(2-tailed)= {round(eta,7)}")
                                                                        
#Styling
style = {'description_width': 'initial'}    
b6332 = interactive(anovab6332, {'manual': True},v1=widgets.Dropdown(options=(("Manipulable"),("Measured"))), v2=widgets.Dropdown(options=(("Manipulable"),("Measured"))), ssa="", ssb="", ssab="",sse="")
b6332.children[0].layout = Layout(width='130px')
b6332.children[1].layout = Layout(width='130px')# ,margin = "5px 5px 5px 5px")
b6332.children[2].layout = Layout(width='130px')
b6332.children[3].layout = Layout(width='130px')
b6332.children[4].layout = Layout(width='130px')
b6332.children[5].layout = Layout(width='130px') 

b6332.children[0].description = "<b>Type A</b>"
b6332.children[1].description = "<b>Type B</b>"
b6332.children[2].description = "<b>SSA</b>"
b6332.children[3].description = "<b>SSB</b>"
b6332.children[4].description = "<b>SSAB</b>"
b6332.children[5].description = "<b>SSError</b>"

b6332.children[0].style = style;
b6332.children[1].style = style;
b6332.children[2].style = style;
b6332.children[3].style = style;
b6332.children[4].style = style;
b6332.children[5].style = style;

b6332.children[6].style.button_color="lightblue";
b6332.children[6].description="Calculate Effect Size";
b6332.children[6].style.font_weight = "bold";
b6332.children[6].layout = Layout(width='200px')

controls6332 = VBox([
          HBox([b6332.children[0],b6332.children[1]]),
          HBox([b6332.children[2],b6332.children[3]]),
          HBox([b6332.children[4],b6332.children[5]]),
          HBox([b6332.children[6]]),])
output6332 = b6332.children[-1]

box6332 = VBox([controls6332,output6332])


def anovab6333(v1, v2, ssa, ssb, ssab, sse):
    if v1 == "Manipulable": 
       v1 = float(v1); ssa = float(ssa); sse = float(sse); 
       eta = ssa 
       print(f"p-value(2-tailed)= {round(eta,7)}")
    elif v1 == "Measured" and v2 == "Measured":
       v1 = float(v1); v2 = float(v2); ssa = float(ssa); ssb = float(ssb); ssab = float(ssab); sse = float(sse);
       eta = ssa
       print(f"p-value(2-tailed)= {round(eta,7)}")
    
#Styling
style = {'description_width': 'initial'}    
b6333 = interactive(anovab6333, {'manual': True},v1=widgets.Dropdown(options=(("Manipulable"),("Measured"))), v2=widgets.Dropdown(options=(("Manipulable"),("Measured"))), ssa="", ssb="", ssab="",sse="")
b6333.children[0].layout = Layout(width='130px')
b6333.children[1].layout = Layout(width='130px')# ,margin = "5px 5px 5px 5px")
b6333.children[2].layout = Layout(width='130px')
b6333.children[3].layout = Layout(width='130px')
b6333.children[4].layout = Layout(width='130px')
b6333.children[5].layout = Layout(width='130px') 

b6333.children[0].description = "<b>Type A</b>"
b6333.children[1].description = "<b>Type B</b>"
b6333.children[2].description = "<b>SSA</b>"
b6333.children[3].description = "<b>SSB</b>"
b6333.children[4].description = "<b>SSAB</b>"
b6333.children[5].description = "<b>SSError</b>"

b6333.children[0].style = style;
b6333.children[1].style = style;
b6333.children[2].style = style;
b6333.children[3].style = style;
b6333.children[4].style = style;
b6333.children[5].style = style;

b6333.children[6].style.button_color="lightblue";
b6333.children[6].description="Calculate Effect Size";
b6333.children[6].style.font_weight = "bold";
b6333.children[6].layout = Layout(width='200px')

controls6333 = VBox([
          HBox([b6333.children[0],b6333.children[1]]),
          HBox([b6333.children[2],b6333.children[3]]),
          HBox([b6333.children[4],b6333.children[5]]),
          HBox([b6333.children[6]]),])
output6333 = b6333.children[-1]

box6333 = VBox([controls6333,output6333])
                                                                     
                                                                               
b633_box = widgets.Dropdown(options=(("1 Variable",box6331),("2 Variables",box6332), ("3 Variables",box6333)))
b633_box.layout = Layout(width = "350px")
b633_box.description = '<p <span style ="color: blue; font-weight: bold; font-size: 100%;"> How Many Variables Do You Have? </span> </p>'
b633_box.style = style

def view(x=""):
    display(x)
ANOVA633 = interactive(view,x=b633_box)
ANOVA633.layout = Layout(margin="5px", padding="0px", width = "auto", height = "auto")
                                                                   
b6box31 = VBox([bbox3_1, ANOVA631])
b6box31.layout = Layout(margin="0px", padding="0px", width = "430px", height = "auto")

b6box32 = VBox([bbox3_2, ANOVA632])
b6box33 = VBox([bbox3_3, ANOVA633])
b6box312 = HBox([b6box31, bbox3_4, b6box32])
b6box312.children[1].layout = Layout(margin="0px 0px 0px 0px", padding="0px 0px 0px 0px", width = "10px")                                                                 


b6box3 = VBox([b6box312, b6box33])
b6box3.layout = Layout(border="solid 5px lightblue", margin="5px 5px 5px 5px", padding="0px 0px 0px 0px", width = "960px", height = "790px")                                                                 

b6_box3 = VBox([bbox3, b6box3]) 
                
################################################ Box3 Final ####################################################################

box6 = HBox([b6_box1, b6_box2 , b6_box3])
box6.layout = Layout(border="solid 2px lightcoral", width = "1700px", height = "800px")


############################################## ESEK final #######################################################
#Create an accordion and add mystyle class on its first child widget
ESEK = widgets.Accordion(children=[box1, box2, box3, box4, box5, box6], titles=('', '', '', '', '', '', '', '')).add_class("parentstyle")
#Add a custom style tag to the notebook, you can use dev tool to inspect the class names
display(HTML("<style>.parentstyle > .p-Accordion-child > .p-Collapse-header{background-color:lightgray; font-size: 24px; width: 750px; text-align: left}</style>"))
#Now the background of the title bars become yellow
ESEK.set_title(0, '1. One Sample with a known variance (Z-test)')
ESEK.set_title(1, '2. One Sample with an unknown variance (t-test)')
ESEK.set_title(2, '3. One Sample Proportion (Z-test)')
ESEK.set_title(3, '4. Two independent means (t-Test & Z-test)')
ESEK.set_title(4, '5. Two paired/dependent/matched/correlated means (t-Test)')
ESEK.set_title(5, '6. Analysis of variance - ANOVA')
ESEK.selected_index = None

display(ESEK);

display(HTML('''<style>[data-mime-type="application/vnd.jupyter.stdout"] pre { color:blue; font-size:120%; display: inline-block; overflow-wrap: break-word;
word-wrap: break-word; word-break: normal; line-break: strict; hyphens: none; -webkit-hyphens: none; -moz-hyphens: none;}</style>'''))

end_time = datetime.now()
print('This is an alpha version so if you notice any problems or bugs please notify me at eldadkeha@gmail.com, enoy :)  {}'.format(end_time - start_time))
###############################################################################################################################
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-c0e776da072c> in <module>()
#      27 start_time = datetime.now()
#      28
# ---> 29 pic1 = Image("https://raw.githubusercontent.com/eldadkeha/ESEK/new-branch/Pics/Bessels.png")
#      30
#      31
#
# /usr/local/lib/python3.7/dist-packages/ipywidgets/widgets/widget_media.py in __init__(self, *args, **kwargs)
#     157
#     158     def __init__(self, *args, **kwargs):
# --> 159         super(Image, self).__init__(*args, **kwargs)
#     160
#     161     @classmethod
#
# TypeError: __init__() takes 1 positional argument but 2 were given
